# %% [markdown]
# ### SQLAlchemy pre-configuration

# %%
# !pip install snowflake-sqlalchemy ipython-sql
# Out:
# Requirement already satisfied: snowflake-sqlalchemy in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: ipython-sql in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: sqlalchemy<2.0.0,>=1.4.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-sqlalchemy) (1.4.50)
# Requirement already satisfied: snowflake-connector-python<4.0.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-sqlalchemy) (3.6.0)
# Requirement already satisfied: prettytable<1 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython>=1.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython-sql) (8.18.1)
# Requirement already satisfied: sqlparse in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython>=1.0->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython>=1.0->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython>=1.0->ipython-sql) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython>=1.0->ipython-sql) (2.17.2)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython>=1.0->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython>=1.0->ipython-sql) (5.14.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (1.16.0)
# Requirement already satisfied: cryptography<42.0.0,>=3.1.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (41.0.7)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=16.2.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (23.3.0)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.8.0)
# Requirement already satisfied: pytz in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.31.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2023.11.17)
# Requirement already satisfied: typing-extensions<5,>=4.3 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (4.8.0)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.4.0)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (3.11.0)
# Requirement already satisfied: tomlkit in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (0.12.3)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from sqlalchemy<2.0.0,>=1.4.0->snowflake-sqlalchemy) (3.0.2)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=1.0->ipython-sql) (0.2.12)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from requests<3.0.0->snowflake-connector-python<4.0.0->snowflake-sqlalchemy) (2.1.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/iceberg-lab/lib/python3.12/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)

# %%
import re
from os.path import expanduser
from snowflake.sqlalchemy import URL

USER_PATH = expanduser("~")
# set CONNECTION_KEY to the same name defined in the local SnowSQL configuration file
CONNECTION_KEY = "training-jramizares"

with open(f'{USER_PATH}/.snowsql/config') as f:
    connection = {}
    skip_mode = False
    connection_key = None
    for line in f:
        buffer = line.strip()
        if (buffer is not None) and (buffer != "") and (buffer[0] != "#"):
            if buffer[0] == "[":
                result = re.search(r"\[connections\.(.*)\]", buffer)
                if result is not None and result.group(1) is not None:
                    if connection_key is not None and not skip_mode:
                        connection[connection_key] = config
                    connection_key = result.group(1)
                    if connection_key != "example":
                        config = {}
                        skip_mode = False
                    else:
                        skip_mode = True
                else:
                    if connection_key:
                        connection[connection_key] = config
                    skip_mode = True
            elif not skip_mode:
                (key, value) = buffer.replace(" ", "").split("=")
                config[key] = value
    

def strip_quotes(v):
    if v is not None:
        return v.replace("'", "").replace("\"", "")
    else:
        return v

SNOW_LOCATOR = strip_quotes(connection[CONNECTION_KEY]["accountname"]) if "accountname" in connection[CONNECTION_KEY] else None
SNOW_USER = strip_quotes(connection[CONNECTION_KEY]["username"]) if "username" in connection[CONNECTION_KEY] else None
SNOW_PASSWD = strip_quotes(connection[CONNECTION_KEY]["password"]) if "password" in connection[CONNECTION_KEY] else None
SNOW_DB = strip_quotes(connection[CONNECTION_KEY]["database"]) if "database" in connection[CONNECTION_KEY] else None
SNOW_WAREHOUSE = strip_quotes(connection[CONNECTION_KEY]["warehouse"]) if "warehouse" in connection[CONNECTION_KEY] else None
SNOW_ROLE = strip_quotes(connection[CONNECTION_KEY]["role"]) if "role" in connection[CONNECTION_KEY] else None

if (SNOW_LOCATOR is not None) and (SNOW_USER is not None) and (SNOW_PASSWD is not None) and \
    (SNOW_DB is not None) and (SNOW_WAREHOUSE is not None) and (SNOW_ROLE is not None):
    # %reload_ext sql
    # %sql snowflake://{SNOW_USER}:{SNOW_PASSWD}@{SNOW_LOCATOR}/{SNOW_DB}?role={SNOW_ROLE}&warehouse={SNOW_WAREHOUSE}
else:
    raise Exception("One or more of the following connection parameters is not defined: accountname, " \
        "username, password, database, warehouse, role")

# %% [markdown]
# ### SRR Resources
#
# - Training
#     - Engineering
#         - [Iceberg Tables Training for Support](https://snowflakecomputing.atlassian.net/wiki/spaces/CustomerSupport/pages/3028713756/Iceberg+Tables+Training+for+Support)
#     - Support
#         - [Intro to Iceberg Tables - Key Concepts training](https://snowflake.zoom.us/rec/share/997cOWJYC6rBIuyzs2P02oD8f28M7dzWj0ygDG9NuIhw3uti2EUqq8_h1m9VUQ8l.dpBvyZ9p_YEQVkOx)
#             - Passcode: <code>AAPQ&W5$</code>
# - Runbook(s)
#     - [Iceberg Support Runbook](https://docs.google.com/document/d/18MjH6n3ypi4VEbs5_wa_Vpxgi0XtVWCLW4_EEe7DBLQ/edit#heading=h.1bu2wjpos1k9)
# - Product documentation
#     - [Iceberg tables](https://docs.snowflake.com/en/user-guide/tables-iceberg)

# %% [markdown]
# ### What is Apache Iceberg?
#
# [Apache Iceberg](https://iceberg.apache.org/docs/latest/) is an open-source table format specification developed for huge analytic datasets.

# %% [markdown]
# ### What are Iceberg Tables?
#
# Iceberg tables are a new table type designed to support the [Apache Iceberg table specification](https://iceberg.apache.org/spec/) to represent a large collection of slowly-changing files on a distributed file system (AWS S3, Azure Blob, Google Cloud Storage) with performance close to that of native Snowflake tables.
#
# The architecture of an Apache Iceberg table is defined as three distinct layers:
# - [Iceberg Catalog](https://iceberg.apache.org/concepts/catalog/#iceberg-catalogs) - Used to manage a collection of tables</li>
# - [Metadata](https://iceberg.apache.org/spec/#specification) - Used to manage table states in a catalog through a combination of metadata files (JSON), manifest lists (Avro), and manifest files (Avro)
# - Data - Collection of files that represent the data for all tables in the catalog
#
# <div>
# <img src="https://iceberg.apache.org/img/iceberg-metadata.png" width="50%"/>
# </div>
#
#
# Snowflake supports Iceberg tables with externally managed catalogs (<strong>unmanaged</strong>) and natively managed catalogs (<strong>managed</strong>).
#
# The following catalog types are supported for unmanaged iceberg tables:
# - [AWS Glue data catalog](https://docs.aws.amazon.com/glue/latest/dg/catalog-and-crawler.html)
# - Object storage
#     - Iceberg
#     - Loose parquet (PrPr)
#
# To create an unmanaged Iceberg table, you will need to configure:
# - [EXTERNAL VOLUME](https://docs.snowflake.com/sql-reference/sql/create-external-volume) - Defines the location(s) for the external catalog, metadata, and data
# - [CATALOG INTEGRATION](https://docs.snowflake.com/en/sql-reference/sql/create-catalog-integration) - Defines the details of the external catalog

# %% [markdown]
# ### Exercise 0: Cleanup from previous notebook
#
# Execute the cell below to drop the Snowflake objects created in this exercise.

# %%
# %%sql
#
# use role support_rl;
# drop database if exists {SNOW_USER}_iceberg_db;
# drop integration if exists {SNOW_USER}_iceberg_os_catalog_int;
# drop integration if exists {SNOW_USER}_os_iceberg_cat_int;
# drop integration if exists {SNOW_USER}_glue_cat_int;
# drop external volume if exists {SNOW_USER}_ext_vol;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [('Drop statement executed successfully (JRAMIZARES_EXT_VOL already dropped).',)]

# %% [markdown]
# ### Exercise 1: Create an unmanaged AWS Iceberg table (type=OBJECT_STORE)
# <u>Prerequisites</u>:
# 1. You must have a personal AWS S3 bucket in <code>us-west-2</code>
# 2. You must have an AWS IAM policy that allows read/write access to your personal AWS S3 bucket
# 3. You must have an AWS IAM role that is assigned the AWS IAM policy (2)

# %%
# Replace <MY_OS_S3_BUCKET> with the name of your bucket in us-west-2
MY_OS_S3_BUCKET='jan-us-west-2'
# Replace <MY_OS_S3_IAM_ROLE_ARN> with your IAM AWS S3 access role ARN
MY_OS_S3_IAM_ROLE_ARN='arn:aws:iam::094271313368:role/jramizares-role'

# %% [markdown]
# #### Step 1: Create an AWS Iceberg table using AWS Athena
# NOTE: Run the cell below to generate instructions

# %%
from IPython.display import Markdown as md

SOURCE_TABLE='kterada_db.kt_glue_iceberg_tpcds_sf10tcl_web_sales'
TARGET_DB_NAME=SNOW_USER + '_db'
TARGET_TABLE_NAME='iceberg_tpcds_sf10tcl_web_sales_t'

here = """
<u>Instructions</u>:
1. Login to the AWS CE-Sandbox Console via [SnowBiz Okta](https://snowbiz.okta.com/)
2. Navigate to the [AWS Athena query editor](https://us-west-2.console.aws.amazon.com/athena/home?region=us-west-2#/query-editor) in <code>us-west-2</code>
3. Execute the following SQL to create a new database:
```
create database {db_name};
```
4. Execute the following SQL to create an AWS Iceberg table:
```
create table {db_name}.{table_name} with (table_type='iceberg', location='s3://{my_os_s3_bucket}/iceberg_feature_lab/tpcds_sf10tcl/web_sales/', is_external=false)
as (select * from {source_table} limit 1000);
```
""".format(my_os_s3_bucket=MY_OS_S3_BUCKET, username=SNOW_USER, db_name=TARGET_DB_NAME, table_name=TARGET_TABLE_NAME, source_table=SOURCE_TABLE)

md(here)
# Out:
# <u>Instructions</u>:
# 1. Login to the AWS CE-Sandbox Console via [SnowBiz Okta](https://snowbiz.okta.com/)
# 2. Navigate to the [AWS Athena query editor](https://us-west-2.console.aws.amazon.com/athena/home?region=us-west-2#/query-editor) in <code>us-west-2</code>
# 3. Execute the following SQL to create a new database:
# ```
# create database jramizares_db;
# ```
# 4. Execute the following SQL to create an AWS Iceberg table:
# ```
# create table jramizares_db.iceberg_tpcds_sf10tcl_web_sales_t with (table_type='iceberg', location='s3://jan-us-west-2/iceberg_feature_lab/tpcds_sf10tcl/web_sales/', is_external=false)
# as (select * from kterada_db.kt_glue_iceberg_tpcds_sf10tcl_web_sales limit 1000);
# ```

# %% [markdown]
# #### Step 2: Create an external volume
#
# References:
# - Snowflake Documentation: [Configure an external volume for Iceberg tables](https://docs.snowflake.com/en/user-guide/tables-iceberg-configure-external-volume)

# %%
# %%sql
# use role support_rl;
# create or replace external volume {SNOW_USER}_os_ext_vol
#     storage_locations = (
#         (
#             name = 's3_iceberg_os_unmanaged'
#             storage_provider = 's3'
#             storage_base_url = 's3://{MY_OS_S3_BUCKET}/'
#             storage_aws_role_arn = '{MY_OS_S3_IAM_ROLE_ARN}'
#             encryption = (type='aws_sse_s3')
#         )
#     )
# ;
# desc external volume {SNOW_USER}_os_ext_vol;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 3 rows affected.
# [('', 'ALLOW_WRITES', 'Boolean', 'true', 'true'),
#  ('STORAGE_LOCATIONS', 'STORAGE_LOCATION_1', 'String', '{"NAME":"s3_iceberg_os_unmanaged","STORAGE_PROVIDER":"S3","STORAGE_BASE_URL":"s3://jan-us-west-2/","STORAGE_ALLOWED_LOCATIONS":["s3://jan-us-west-2/* ... (105 characters truncated) ... n:aws:iam::291522143594:user/m3ig0000-s","STORAGE_AWS_EXTERNAL_ID":"ZZB08069_SFCRole=61_gcx1DpQWVo0ZzH8GwaOpI7nypBA=","ENCRYPTION_TYPE":"AWS_SSE_S3"}', ''),
#  ('STORAGE_LOCATIONS', 'ACTIVE', 'String', '', '')]

# %% [markdown]
# NOTE: After creating the external volume, you must update trust relationships in your AWS IAM role based on the `DESCRIBE` output above

# %% [markdown]
# #### Step 3: Create a catalog integration
#
# References:
# - Snowflake Documentation: [Configure a catalog integration for Iceberg tables](https://docs.snowflake.com/en/user-guide/tables-iceberg-configure-catalog-integration)

# %% [markdown]
# ##### OBJECT STORAGE (ICEBERG)

# %%
# %%sql
#
# use role support_rl;
#
# create or replace catalog integration {SNOW_USER}_os_iceberg_cat_int
#     catalog_source = object_store
#     table_format = iceberg
#     enabled = true
# ;
# desc integration {SNOW_USER}_os_iceberg_cat_int;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 4 rows affected.
# [('ENABLED', 'Boolean', 'true', 'false'),
#  ('CATALOG_SOURCE', 'String', 'OBJECT_STORE', ''),
#  ('TABLE_FORMAT', 'String', 'ICEBERG', ''),
#  ('COMMENT', 'String', '', '')]

# %% [markdown]
# #### Step 4: Create the unmanaged Snowflake Iceberg table
#
# References:
# - Snowflake Documentation: [Create an Iceberg table](https://docs.snowflake.com/user-guide/tables-iceberg-create)

# %%
# %%sql
#
# use role support_rl;
# create warehouse if not exists {SNOW_USER}_wh warehouse_size='xsmall';
# create database if not exists {SNOW_USER}_db;
# create schema if not exists {SNOW_USER}_db.iceberg;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [('ICEBERG already exists, statement succeeded.',)]

# %% [markdown]
# ##### OBJECT STORE (ICEBERG)

# %%
# Replace <MY_OS_ICEBERG_TABLE_METADATA_FILENAME> with the full name of AWS Iceberg table metadata filename in the 
# iceberg_feature_lab/tpcds_sf10tcl/web_sales/ path of your us-west-2 bucket
MY_OS_ICEBERG_TABLE_METADATA_FILENAME='00000-31cc49ef-7184-42cd-a697-2e6fc32863e1.metadata.json'

# %%
# %%sql
#
# use role support_rl;
# use warehouse {SNOW_USER}_wh;
# create or replace iceberg table {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t
#     external_volume = {SNOW_USER}_os_ext_vol
#     catalog = {SNOW_USER}_os_iceberg_cat_int
#     metadata_file_path = 'iceberg_feature_lab/tpcds_sf10tcl/web_sales/metadata/{MY_OS_ICEBERG_TABLE_METADATA_FILENAME}'
# ;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [('Table JRAMIZARES_UNMANAGED_OS_ICEBERG_WEB_SALES_T successfully created.',)]

# %%
# %%sql
#
# use role support_rl;
# use warehouse {SNOW_USER}_wh;
# select
#     count(*)
# from {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t
# where true
# ;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [(1000,)]

# %%
# %%sql
#
# use role support_rl;
# use warehouse {SNOW_USER}_wh;
# select
#     *
# from {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t
# where true
# limit 100
# ;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 100 rows affected.
# [(Decimal('45450322.00'), 'AAAAAAAACFEIFLCA', Decimal('107525.00'), Decimal('4348.00'), Decimal('20190771.00'), Decimal('2451698.00'), Decimal('2451668.00'), 'Dr.', 'Clyde', 'Johnson', 'N', Decimal('18.00'), Decimal('7.00'), Decimal('1967.00'), 'BELGIUM', None, 'Clyde.Johnson@05T4omXCqE8o0AR.com', '2452332'),
#  (Decimal('45450323.00'), 'AAAAAAAADFEIFLCA', Decimal('555423.00'), Decimal('5126.00'), Decimal('13787182.00'), Decimal('2449772.00'), Decimal('2449742.00'), 'Dr.', 'Todd', 'Jones', 'Y', Decimal('19.00'), Decimal('5.00'), Decimal('1956.00'), 'GEORGIA', None, 'Todd.Jones@qpfFzHa25n.org', '2452393'),
#  (Decimal('45450324.00'), 'AAAAAAAAEFEIFLCA', Decimal('1081796.00'), Decimal('1018.00'), Decimal('2803887.00'), Decimal('2451086.00'), Decimal('2451056.00'), 'Ms.', 'Jessica', 'Wilson', 'N', Decimal('30.00'), Decimal('9.00'), Decimal('1986.00'), 'RÉUNION', None, 'Jessica.Wilson@1aejCR8S.org', '2452568'),
#  (Decimal('45450325.00'), 'AAAAAAAAFFEIFLCA', Decimal('1464097.00'), Decimal('1919.00'), Decimal('28482141.00'), Decimal('2451805.00'), Decimal('2451775.00'), 'Mr.', 'Christopher', 'Jones', 'N', Decimal('2.00'), Decimal('8.00'), Decimal('1985.00'), 'GEORGIA', None, 'Christopher.Jones@udEI.edu', '2452366'),
#  (Decimal('45450326.00'), 'AAAAAAAAGFEIFLCA', Decimal('474105.00'), Decimal('4926.00'), Decimal('7957347.00'), Decimal('2451823.00'), Decimal('2451793.00'), 'Dr.', 'Casey', 'Osborne', 'Y', Decimal('24.00'), Decimal('3.00'), Decimal('1939.00'), 'PALAU', None, 'Casey.Osborne@OLVka4Ni1p59S.org', '2452450'),
#  (Decimal('45450327.00'), 'AAAAAAAAHFEIFLCA', Decimal('632578.00'), Decimal('6310.00'), Decimal('2191242.00'), Decimal('2452420.00'), Decimal('2452390.00'), 'Dr.', 'Matthew', 'Brooks', 'N', Decimal('25.00'), Decimal('2.00'), Decimal('1991.00'), 'NETHERLANDS', None, 'Matthew.Brooks@B1MYXymcYbErv.com', '2452482'),
#  (Decimal('45450328.00'), 'AAAAAAAAIFEIFLCA', Decimal('164121.00'), Decimal('4655.00'), Decimal('24795589.00'), Decimal('2449413.00'), Decimal('2449383.00'), 'Sir', 'Larry', 'Martin', 'Y', Decimal('23.00'), Decimal('8.00'), Decimal('1984.00'), 'BELIZE', None, 'Larry.Martin@VrQnhjd.com', '2452365'),
#  (Decimal('45450329.00'), 'AAAAAAAAJFEIFLCA', Decimal('932262.00'), Decimal('3572.00'), Decimal('24018082.00'), Decimal('2452204.00'), Decimal('2452174.00'), 'Ms.', 'Jeanette', 'White', 'Y', Decimal('29.00'), Decimal('9.00'), Decimal('1937.00'), 'BELARUS', None, 'Jeanette.White@FSuX8TE.com', '2452445'),
#  (Decimal('45450330.00'), 'AAAAAAAAKFEIFLCA', Decimal('68098.00'), Decimal('101.00'), Decimal('28172104.00'), Decimal('2450779.00'), Decimal('2450749.00'), 'Dr.', 'Christy', 'Collins', 'Y', Decimal('25.00'), Decimal('3.00'), Decimal('1949.00'), 'ARUBA', None, 'Christy.Collins@yonCligsyhQ.org', '2452496'),
#  (Decimal('45450331.00'), 'AAAAAAAALFEIFLCA', Decimal('917761.00'), Decimal('2710.00'), Decimal('5456459.00'), Decimal('2451188.00'), Decimal('2451158.00'), 'Mr.', 'Michael', 'Alvarado', 'Y', Decimal('4.00'), Decimal('2.00'), Decimal('1940.00'), 'HONDURAS', None, 'Michael.Alvarado@QeRVi8VKA.edu', '2452356'),
#  (Decimal('45450332.00'), 'AAAAAAAAMFEIFLCA', Decimal('706994.00'), Decimal('6199.00'), Decimal('26455804.00'), Decimal('2452310.00'), Decimal('2452280.00'), 'Ms.', 'Edna', 'Wilson', 'N', Decimal('15.00'), Decimal('1.00'), Decimal('1941.00'), 'BURKINA FASO', None, 'Edna.Wilson@txYllpBQVG0h.edu', '2452290'),
#  (Decimal('45450333.00'), 'AAAAAAAANFEIFLCA', Decimal('413898.00'), Decimal('5113.00'), Decimal('30061128.00'), Decimal('2449294.00'), Decimal('2449264.00'), 'Sir', 'Royce', 'Jacobs', 'Y', Decimal('4.00'), Decimal('4.00'), Decimal('1928.00'), 'MOZAMBIQUE', None, 'Royce.Jacobs@6AncUR.edu', '2452595'),
#  (Decimal('45450334.00'), 'AAAAAAAAOFEIFLCA', Decimal('1223787.00'), Decimal('2275.00'), Decimal('31613916.00'), Decimal('2451156.00'), Decimal('2451126.00'), 'Mrs.', 'Angel', 'Williamson', 'Y', Decimal('27.00'), Decimal('3.00'), Decimal('1933.00'), 'CHILE', None, 'Angel.Williamson@9.edu', '2452310'),
#  (Decimal('45450335.00'), 'AAAAAAAAPFEIFLCA', Decimal('1683934.00'), Decimal('4552.00'), Decimal('23949970.00'), Decimal('2452658.00'), Decimal('2452628.00'), 'Mr.', 'Cesar', 'Ragland', 'Y', Decimal('29.00'), Decimal('9.00'), Decimal('1958.00'), 'TIMOR-LESTE', None, 'Cesar.Ragland@pJJbpDn2tlzO.com', '2452549'),
#  (Decimal('45450336.00'), 'AAAAAAAAAGEIFLCA', Decimal('334845.00'), Decimal('5863.00'), Decimal('29750128.00'), Decimal('2449452.00'), Decimal('2449422.00'), 'Sir', 'Tobias', 'Lee', 'N', Decimal('19.00'), Decimal('5.00'), Decimal('1947.00'), 'BRAZIL', None, 'Tobias.Lee@aZr3cl6V4OVMKcyan.com', '2452372'),
#  (Decimal('45450337.00'), 'AAAAAAAABGEIFLCA', Decimal('203387.00'), Decimal('5929.00'), Decimal('22110518.00'), Decimal('2451861.00'), Decimal('2451831.00'), 'Sir', 'James', 'James', 'N', Decimal('9.00'), Decimal('1.00'), Decimal('1969.00'), 'GUADELOUPE', None, 'James.James@bhl.org', '2452454'),
#  (Decimal('45450338.00'), 'AAAAAAAACGEIFLCA', Decimal('360235.00'), Decimal('5513.00'), Decimal('11396744.00'), Decimal('2450668.00'), Decimal('2450638.00'), 'Mrs.', 'Sylvia', 'Staley', 'N', Decimal('29.00'), Decimal('7.00'), Decimal('1970.00'), 'TAJIKISTAN', None, 'Sylvia.Staley@vQqLoLsdRfAvZc.org', '2452298'),
#  (Decimal('45450339.00'), 'AAAAAAAADGEIFLCA', Decimal('810820.00'), Decimal('406.00'), Decimal('23856392.00'), Decimal('2449729.00'), Decimal('2449699.00'), 'Miss', 'Joyce', 'Smithson', 'Y', Decimal('27.00'), Decimal('8.00'), Decimal('1973.00'), 'LATVIA', None, 'Joyce.Smithson@KVNiXRGx41S.com', '2452406'),
#  (Decimal('45450340.00'), 'AAAAAAAAEGEIFLCA', Decimal('34841.00'), Decimal('814.00'), Decimal('4581634.00'), Decimal('2451471.00'), Decimal('2451441.00'), 'Sir', 'John', 'Roberts', 'Y', Decimal('18.00'), Decimal('7.00'), Decimal('1952.00'), 'GAMBIA', None, 'John.Roberts@C3LaRJ9U.edu', '2452337'),
#  (Decimal('45450341.00'), 'AAAAAAAAFGEIFLCA', Decimal('855130.00'), Decimal('5193.00'), Decimal('8725656.00'), Decimal('2451524.00'), Decimal('2451494.00'), 'Mr.', 'Roland', 'Miller', 'Y', Decimal('21.00'), Decimal('7.00'), Decimal('1964.00'), 'NIUE', None, 'Roland.Miller@Cca9.edu', '2452520'),
#  (Decimal('45450342.00'), 'AAAAAAAAGGEIFLCA', Decimal('198008.00'), Decimal('4476.00'), Decimal('14826591.00'), Decimal('2451941.00'), Decimal('2451911.00'), 'Mrs.', 'Gladys', 'Bennett', 'N', Decimal('23.00'), Decimal('6.00'), Decimal('1946.00'), 'GUADELOUPE', None, 'Gladys.Bennett@hOdm.com', '2452451'),
#  (Decimal('45450343.00'), 'AAAAAAAAHGEIFLCA', Decimal('1223806.00'), Decimal('3100.00'), Decimal('378841.00'), Decimal('2450859.00'), Decimal('2450829.00'), 'Sir', 'Jonathan', 'Gamble', 'Y', Decimal('19.00'), Decimal('5.00'), Decimal('1956.00'), 'TUNISIA', None, 'Jonathan.Gamble@uEJKHscP0h5D1HIm.org', '2452578'),
#  (Decimal('45450344.00'), 'AAAAAAAAIGEIFLCA', Decimal('1089724.00'), Decimal('1783.00'), Decimal('1821395.00'), Decimal('2449819.00'), Decimal('2449789.00'), 'Mrs.', 'Ciara', 'Gould', 'Y', Decimal('12.00'), Decimal('3.00'), Decimal('1978.00'), 'MAYOTTE', None, 'Ciara.Gould@OG1i8818ftY98.org', '2452506'),
#  (Decimal('45450345.00'), 'AAAAAAAAJGEIFLCA', Decimal('879643.00'), Decimal('1127.00'), Decimal('28938258.00'), Decimal('2449201.00'), Decimal('2449171.00'), 'Miss', 'Evelyn', 'Jordan', 'Y', Decimal('5.00'), Decimal('9.00'), Decimal('1990.00'), 'IRAQ', None, 'Evelyn.Jordan@oDA7VevqFrSl4VbflZG.edu', '2452380'),
#  (Decimal('45450346.00'), 'AAAAAAAAKGEIFLCA', Decimal('47729.00'), Decimal('466.00'), Decimal('8521650.00'), Decimal('2451318.00'), Decimal('2451288.00'), 'Mr.', 'Allan', 'Williams', 'N', Decimal('9.00'), Decimal('5.00'), Decimal('1961.00'), 'FAROE ISLANDS', None, 'Allan.Williams@qxGVE.com', '2452598'),
#  (Decimal('45450347.00'), 'AAAAAAAALGEIFLCA', Decimal('1554458.00'), Decimal('2070.00'), Decimal('25644529.00'), Decimal('2452320.00'), Decimal('2452290.00'), 'Dr.', 'John', 'Nielsen', 'N', Decimal('12.00'), Decimal('1.00'), Decimal('1925.00'), 'TIMOR-LESTE', None, 'John.Nielsen@X9yso3.org', '2452540'),
#  (Decimal('45450348.00'), 'AAAAAAAAMGEIFLCA', Decimal('1419938.00'), Decimal('6897.00'), Decimal('3943456.00'), Decimal('2452082.00'), Decimal('2452052.00'), 'Dr.', 'Gregory', 'Rogers', 'Y', Decimal('14.00'), Decimal('11.00'), Decimal('1960.00'), 'GERMANY', None, 'Gregory.Rogers@KE.com', '2452498'),
#  (Decimal('45450349.00'), 'AAAAAAAANGEIFLCA', Decimal('1030208.00'), Decimal('5154.00'), Decimal('9718147.00'), Decimal('2451237.00'), Decimal('2451207.00'), 'Dr.', 'Alice', 'Cordero', 'Y', Decimal('22.00'), Decimal('2.00'), Decimal('1936.00'), 'ARMENIA', None, 'Alice.Cordero@qkPpMs0QBsaQg2gj3.com', '2452386'),
#  (Decimal('45450350.00'), 'AAAAAAAAOGEIFLCA', Decimal('1638059.00'), Decimal('1096.00'), Decimal('13873380.00'), Decimal('2450536.00'), Decimal('2450506.00'), 'Ms.', 'Linda', 'Mccarthy', 'N', Decimal('18.00'), Decimal('1.00'), Decimal('1975.00'), 'NIGERIA', None, 'Linda.Mccarthy@vTdr1Tets756Rb.com', '2452544'),
#  (Decimal('45450351.00'), 'AAAAAAAAPGEIFLCA', Decimal('805603.00'), Decimal('6149.00'), Decimal('2925448.00'), Decimal('2451725.00'), Decimal('2451695.00'), 'Dr.', 'Rebecca', 'Goodman', 'N', Decimal('28.00'), Decimal('2.00'), Decimal('1967.00'), 'MONACO', None, 'Rebecca.Goodman@Mkf2glt4B323B.com', '2452533'),
#  (Decimal('45450352.00'), 'AAAAAAAAAHEIFLCA', Decimal('991270.00'), Decimal('1676.00'), Decimal('1580529.00'), Decimal('2449858.00'), Decimal('2449828.00'), 'Sir', 'Keith', 'Reed', 'N', Decimal('19.00'), Decimal('10.00'), Decimal('1927.00'), 'HONG KONG', None, 'Keith.Reed@sG9B0HEa.edu', '2452549'),
#  (Decimal('45450353.00'), 'AAAAAAAABHEIFLCA', Decimal('637074.00'), Decimal('839.00'), Decimal('19539804.00'), Decimal('2450907.00'), Decimal('2450877.00'), 'Sir', 'Earl', 'Young', 'N', Decimal('15.00'), Decimal('6.00'), Decimal('1977.00'), 'YEMEN', None, 'Earl.Young@lzTXKGhshty3yCg6.edu', '2452359'),
#  (Decimal('45450354.00'), 'AAAAAAAACHEIFLCA', Decimal('399977.00'), Decimal('3737.00'), Decimal('29420744.00'), Decimal('2449555.00'), Decimal('2449525.00'), 'Sir', 'David', 'Holmes', 'N', Decimal('15.00'), Decimal('8.00'), Decimal('1986.00'), 'SOMALIA', None, 'David.Holmes@TrbYSjOlzRtBQ.org', '2452557'),
#  (Decimal('45450355.00'), 'AAAAAAAADHEIFLCA', Decimal('405437.00'), Decimal('1481.00'), Decimal('25251925.00'), Decimal('2452068.00'), Decimal('2452038.00'), 'Dr.', 'Roy', 'Vigil', 'N', Decimal('24.00'), Decimal('10.00'), Decimal('1961.00'), 'SLOVENIA', None, 'Roy.Vigil@76.org', '2452318'),
#  (Decimal('45450356.00'), 'AAAAAAAAEHEIFLCA', Decimal('747889.00'), Decimal('4461.00'), Decimal('12830986.00'), Decimal('2450138.00'), Decimal('2450108.00'), 'Dr.', 'Nathan', 'Nelms', 'N', Decimal('23.00'), Decimal('9.00'), Decimal('1989.00'), 'MONACO', None, 'Nathan.Nelms@ee.edu', '2452446'),
#  (Decimal('45450357.00'), 'AAAAAAAAFHEIFLCA', Decimal('1373188.00'), Decimal('2386.00'), Decimal('3511584.00'), Decimal('2450276.00'), Decimal('2450246.00'), 'Ms.', 'Charlotte', 'Edmondson', 'N', Decimal('21.00'), Decimal('5.00'), Decimal('1946.00'), 'MONTSERRAT', None, 'Charlotte.Edmondson@y7x6NKUBjuG.org', '2452344'),
#  (Decimal('45450358.00'), 'AAAAAAAAGHEIFLCA', Decimal('914690.00'), Decimal('4045.00'), Decimal('1981047.00'), Decimal('2450559.00'), Decimal('2450529.00'), 'Dr.', 'Margaret', 'Mcgee', 'N', Decimal('7.00'), Decimal('11.00'), Decimal('1939.00'), 'GHANA', None, 'Margaret.Mcgee@ta2CsLmVvUr.org', '2452283'),
#  (Decimal('45450359.00'), 'AAAAAAAAHHEIFLCA', Decimal('110101.00'), Decimal('3726.00'), Decimal('2748551.00'), Decimal('2451967.00'), Decimal('2451937.00'), 'Miss', 'Ann', 'Mcdonald', 'N', Decimal('6.00'), Decimal('6.00'), Decimal('1952.00'), 'HONG KONG', None, 'Ann.Mcdonald@gvUFDDY.org', '2452491'),
#  (Decimal('45450360.00'), 'AAAAAAAAIHEIFLCA', None, None, Decimal('1456412.00'), Decimal('2451811.00'), None, None, 'Edith', 'Garrett', None, None, Decimal('1.00'), Decimal('1932.00'), 'TIMOR-LESTE', None, 'Edith.Garrett@vDNtklzb3Uh.org', None),
#  (Decimal('45450361.00'), 'AAAAAAAAJHEIFLCA', Decimal('389886.00'), Decimal('4148.00'), Decimal('32113610.00'), Decimal('2449789.00'), Decimal('2449759.00'), 'Mrs.', 'Michelle', 'Soto', 'Y', Decimal('5.00'), Decimal('5.00'), Decimal('1929.00'), 'SOLOMON ISLANDS', None, 'Michelle.Soto@uogm.com', '2452484'),
#  (Decimal('45450362.00'), 'AAAAAAAAKHEIFLCA', Decimal('97183.00'), Decimal('4772.00'), Decimal('5786761.00'), Decimal('2450476.00'), Decimal('2450446.00'), 'Dr.', 'Derrick', 'Shorter', 'N', Decimal('29.00'), Decimal('12.00'), Decimal('1937.00'), 'GUINEA', None, 'Derrick.Shorter@CYBFg.org', '2452523'),
#  (Decimal('45450363.00'), 'AAAAAAAALHEIFLCA', Decimal('321383.00'), Decimal('4504.00'), Decimal('22021578.00'), Decimal('2449941.00'), Decimal('2449911.00'), 'Dr.', 'James', 'Chambers', 'N', Decimal('2.00'), Decimal('1.00'), Decimal('1963.00'), 'ANTIGUA AND BARBUDA', None, 'James.Chambers@FMkB9syMCc.org', '2452372'),
#  (Decimal('45450364.00'), 'AAAAAAAAMHEIFLCA', Decimal('844690.00'), Decimal('4348.00'), Decimal('122406.00'), Decimal('2449940.00'), Decimal('2449910.00'), 'Mr.', 'Charles', 'Morales', 'N', Decimal('14.00'), Decimal('8.00'), Decimal('1933.00'), 'VIET NAM', None, 'Charles.Morales@IFxP.org', '2452358'),
#  (Decimal('45450365.00'), 'AAAAAAAANHEIFLCA', Decimal('282314.00'), Decimal('2793.00'), Decimal('1175272.00'), Decimal('2450974.00'), Decimal('2450944.00'), 'Mr.', 'Ralph', 'Stewart', 'N', Decimal('4.00'), Decimal('6.00'), Decimal('1954.00'), 'BERMUDA', None, 'Ralph.Stewart@Kz1AojFnMz.org', '2452352'),
#  (Decimal('45450366.00'), 'AAAAAAAAOHEIFLCA', Decimal('1606025.00'), Decimal('5497.00'), Decimal('8682569.00'), Decimal('2449449.00'), Decimal('2449419.00'), 'Dr.', 'Angela', 'Mckay', 'N', Decimal('10.00'), Decimal('3.00'), Decimal('1975.00'), 'FRANCE', None, 'Angela.Mckay@skxutB.org', '2452335'),
#  (Decimal('45450367.00'), 'AAAAAAAAPHEIFLCA', Decimal('748014.00'), Decimal('1422.00'), Decimal('14794383.00'), Decimal('2450086.00'), Decimal('2450056.00'), 'Miss', 'Brittany', 'Rivera', 'N', Decimal('26.00'), Decimal('12.00'), Decimal('1948.00'), 'UNITED ARAB EMIRATES', None, 'Brittany.Rivera@leX.edu', '2452557'),
#  (Decimal('45450368.00'), 'AAAAAAAAAIEIFLCA', Decimal('1507583.00'), Decimal('623.00'), Decimal('24013663.00'), Decimal('2450915.00'), Decimal('2450885.00'), 'Ms.', 'Elizabeth', 'Orton', 'N', Decimal('20.00'), Decimal('1.00'), Decimal('1929.00'), 'JERSEY', None, 'Elizabeth.Orton@tTQZ7POGFkju.com', '2452642'),
#  (Decimal('45450369.00'), 'AAAAAAAABIEIFLCA', Decimal('1060054.00'), Decimal('3100.00'), Decimal('29521699.00'), Decimal('2451810.00'), Decimal('2451780.00'), 'Sir', 'Gabriel', 'Nagel', 'N', Decimal('4.00'), Decimal('2.00'), Decimal('1956.00'), 'EL SALVADOR', None, 'Gabriel.Nagel@EJY9mBC.com', '2452643'),
#  (Decimal('45450370.00'), 'AAAAAAAACIEIFLCA', Decimal('658409.00'), Decimal('221.00'), Decimal('3120880.00'), Decimal('2451717.00'), Decimal('2451687.00'), 'Dr.', 'Jorge', 'Burns', 'N', Decimal('14.00'), Decimal('12.00'), Decimal('1989.00'), 'PARAGUAY', None, 'Jorge.Burns@qQa2D0mrYsSfds.edu', '2452617'),
#  (Decimal('45450371.00'), 'AAAAAAAADIEIFLCA', Decimal('1722601.00'), Decimal('4023.00'), Decimal('21216198.00'), Decimal('2451485.00'), Decimal('2451455.00'), 'Ms.', 'Elaine', 'Ryan', 'Y', Decimal('2.00'), Decimal('1.00'), Decimal('1964.00'), 'PHILIPPINES', None, 'Elaine.Ryan@K28mYmuDEVmT.org', '2452416'),
#  (Decimal('45450372.00'), 'AAAAAAAAEIEIFLCA', Decimal('1764934.00'), Decimal('1966.00'), Decimal('1434645.00'), Decimal('2449298.00'), Decimal('2449268.00'), 'Sir', 'Oscar', 'Martinson', 'Y', Decimal('5.00'), Decimal('8.00'), Decimal('1964.00'), 'GUADELOUPE', None, 'Oscar.Martinson@kYQC02SoE25Qu.org', '2452433'),
#  (Decimal('45450373.00'), 'AAAAAAAAFIEIFLCA', Decimal('1877134.00'), Decimal('5289.00'), Decimal('16184997.00'), Decimal('2452643.00'), Decimal('2452613.00'), 'Sir', 'David', 'Levine', 'N', Decimal('7.00'), Decimal('8.00'), Decimal('1989.00'), 'ETHIOPIA', None, 'David.Levine@G2umIkS.com', '2452318'),
#  (Decimal('45450374.00'), 'AAAAAAAAGIEIFLCA', Decimal('1520677.00'), Decimal('4065.00'), Decimal('29822300.00'), Decimal('2452623.00'), Decimal('2452593.00'), 'Dr.', 'Marlene', 'Amaya', 'N', Decimal('20.00'), Decimal('4.00'), Decimal('1984.00'), 'SAUDI ARABIA', None, 'Marlene.Amaya@Z7j7D.org', '2452318'),
#  (Decimal('45450375.00'), 'AAAAAAAAHIEIFLCA', Decimal('1882455.00'), Decimal('6663.00'), Decimal('25309271.00'), Decimal('2452101.00'), Decimal('2452071.00'), 'Mr.', 'Joshua', 'Pacheco', 'Y', Decimal('9.00'), Decimal('6.00'), Decimal('1925.00'), 'AFGHANISTAN', None, 'Joshua.Pacheco@rhcJ5.org', '2452431'),
#  (Decimal('45450376.00'), 'AAAAAAAAIIEIFLCA', None, None, Decimal('27446224.00'), None, None, 'Mr.', 'Clyde', None, None, Decimal('28.00'), None, Decimal('1930.00'), 'HONDURAS', None, None, None),
#  (Decimal('45450377.00'), 'AAAAAAAAJIEIFLCA', Decimal('179680.00'), Decimal('6610.00'), Decimal('28583940.00'), Decimal('2450265.00'), Decimal('2450235.00'), 'Mr.', 'Ira', 'Duncan', 'N', Decimal('18.00'), Decimal('4.00'), Decimal('1967.00'), 'MONTENEGRO', None, 'Ira.Duncan@ryn7Fk7.edu', '2452396'),
#  (Decimal('45450378.00'), 'AAAAAAAAKIEIFLCA', Decimal('1719037.00'), Decimal('1865.00'), Decimal('26409493.00'), Decimal('2452503.00'), Decimal('2452473.00'), 'Ms.', 'Sandra', 'Chapman', 'Y', Decimal('20.00'), Decimal('11.00'), Decimal('1929.00'), 'SOMALIA', None, 'Sandra.Chapman@C7.org', '2452301'),
#  (Decimal('45450379.00'), 'AAAAAAAALIEIFLCA', Decimal('1586943.00'), None, Decimal('14047216.00'), Decimal('2451416.00'), Decimal('2451386.00'), 'Sir', 'James', 'Trujillo', 'Y', Decimal('3.00'), Decimal('4.00'), Decimal('1942.00'), None, None, 'James.Trujillo@6XTuItHsA.edu', None),
#  (Decimal('45450380.00'), 'AAAAAAAAMIEIFLCA', None, Decimal('1655.00'), Decimal('29949676.00'), Decimal('2452461.00'), None, None, 'Sun', None, 'Y', Decimal('1.00'), None, None, None, None, None, None),
#  (Decimal('45450381.00'), 'AAAAAAAANIEIFLCA', Decimal('414587.00'), Decimal('5714.00'), Decimal('31980394.00'), Decimal('2449939.00'), Decimal('2449909.00'), 'Mrs.', 'Sarah', 'Johnson', 'N', Decimal('19.00'), Decimal('2.00'), Decimal('1965.00'), 'TONGA', None, 'Sarah.Johnson@KqS0R5KXocF.org', '2452500'),
#  (Decimal('45450382.00'), 'AAAAAAAAOIEIFLCA', Decimal('895573.00'), Decimal('3651.00'), Decimal('7542129.00'), Decimal('2451554.00'), Decimal('2451524.00'), 'Dr.', 'Jonathan', 'Boyd', 'Y', Decimal('24.00'), Decimal('2.00'), Decimal('1960.00'), 'CHRISTMAS ISLAND', None, 'Jonathan.Boyd@PHNBhsznPp.org', '2452414'),
#  (Decimal('45450383.00'), 'AAAAAAAAPIEIFLCA', Decimal('98655.00'), Decimal('5706.00'), Decimal('22243157.00'), Decimal('2450375.00'), Decimal('2450345.00'), 'Dr.', 'Angelica', 'Black', 'N', Decimal('8.00'), Decimal('10.00'), Decimal('1973.00'), 'NETHERLANDS', None, 'Angelica.Black@NXNRoRoJJ4lxZ.edu', '2452447'),
#  (Decimal('45450384.00'), 'AAAAAAAAAJEIFLCA', Decimal('401358.00'), Decimal('3844.00'), Decimal('2721977.00'), Decimal('2451902.00'), Decimal('2451872.00'), 'Mr.', 'Kenneth', 'Tavares', 'N', Decimal('13.00'), Decimal('10.00'), Decimal('1935.00'), 'BRAZIL', None, 'Kenneth.Tavares@afI3.com', '2452385'),
#  (Decimal('45450449.00'), 'AAAAAAAABNEIFLCA', Decimal('620343.00'), Decimal('919.00'), Decimal('32390295.00'), None, None, 'Sir', 'Paul', None, 'Y', None, Decimal('12.00'), None, 'ANGUILLA', None, 'Paul.Billingsley@XjGpnNOp.edu', '2452287'),
#  (Decimal('45450450.00'), 'AAAAAAAACNEIFLCA', Decimal('1910231.00'), Decimal('2657.00'), Decimal('10808683.00'), Decimal('2451883.00'), Decimal('2451853.00'), 'Mr.', 'Howard', 'Tate', 'Y', Decimal('9.00'), Decimal('3.00'), Decimal('1973.00'), 'INDONESIA', None, 'Howard.Tate@CL7nYT0JiSp.org', '2452402'),
#  (Decimal('45450451.00'), 'AAAAAAAADNEIFLCA', Decimal('1792257.00'), Decimal('4559.00'), Decimal('7772414.00'), Decimal('2451434.00'), Decimal('2451404.00'), 'Dr.', 'Meagan', 'Wood', 'N', Decimal('12.00'), Decimal('4.00'), Decimal('1953.00'), 'SAINT HELENA', None, 'Meagan.Wood@uuuoyI.org', '2452455'),
#  (Decimal('45450452.00'), 'AAAAAAAAENEIFLCA', Decimal('79693.00'), Decimal('90.00'), Decimal('11096487.00'), Decimal('2452319.00'), Decimal('2452289.00'), 'Mrs.', 'Dorothy', 'Trotter', 'N', Decimal('28.00'), Decimal('9.00'), Decimal('1961.00'), 'NICARAGUA', None, 'Dorothy.Trotter@cC9gyOV4pTxy.com', '2452392'),
#  (Decimal('45450453.00'), 'AAAAAAAAFNEIFLCA', Decimal('738270.00'), None, Decimal('17472270.00'), None, Decimal('2451438.00'), 'Dr.', 'Juanita', None, None, Decimal('25.00'), None, None, None, None, 'Juanita.Andrews@kgU21ALl9X.com', None),
#  (Decimal('45450454.00'), 'AAAAAAAAGNEIFLCA', Decimal('1197257.00'), Decimal('4352.00'), Decimal('21927447.00'), Decimal('2452650.00'), Decimal('2452620.00'), 'Mr.', 'Shane', 'Brennan', 'Y', Decimal('20.00'), Decimal('5.00'), Decimal('1935.00'), 'EL SALVADOR', None, 'Shane.Brennan@JZ11r4iRu6nQ9.com', '2452433'),
#  (Decimal('45450455.00'), 'AAAAAAAAHNEIFLCA', Decimal('247111.00'), Decimal('855.00'), Decimal('12103046.00'), Decimal('2450019.00'), Decimal('2449989.00'), 'Sir', 'Roy', 'Christian', 'Y', Decimal('2.00'), Decimal('4.00'), Decimal('1945.00'), 'CAPE VERDE', None, 'Roy.Christian@02xhc.org', '2452294'),
#  (Decimal('45450456.00'), 'AAAAAAAAINEIFLCA', Decimal('1229224.00'), Decimal('2264.00'), Decimal('13005257.00'), Decimal('2449667.00'), Decimal('2449637.00'), 'Dr.', 'Tommy', 'Bush', 'N', Decimal('4.00'), Decimal('5.00'), Decimal('1992.00'), 'BERMUDA', None, 'Tommy.Bush@8ayc4mkuUC.com', '2452602'),
#  (Decimal('45450457.00'), 'AAAAAAAAJNEIFLCA', Decimal('1201120.00'), Decimal('4676.00'), Decimal('21722279.00'), Decimal('2452553.00'), Decimal('2452523.00'), 'Dr.', 'Keith', 'Turner', 'N', Decimal('6.00'), Decimal('8.00'), Decimal('1954.00'), 'SAINT HELENA', None, 'Keith.Turner@5THpOOnOpm.edu', '2452404'),
#  (Decimal('45450458.00'), 'AAAAAAAAKNEIFLCA', Decimal('121079.00'), Decimal('3676.00'), Decimal('3737473.00'), Decimal('2451639.00'), Decimal('2451609.00'), 'Dr.', 'Lilia', 'Ackerman', 'Y', Decimal('24.00'), Decimal('10.00'), Decimal('1983.00'), 'PHILIPPINES', None, 'Lilia.Ackerman@bGeEiPPr2sFg6GXj.com', '2452462'),
#  (Decimal('45450459.00'), 'AAAAAAAALNEIFLCA', Decimal('92207.00'), Decimal('5691.00'), Decimal('14399175.00'), Decimal('2449430.00'), Decimal('2449400.00'), 'Sir', 'Paul', 'Taylor', 'N', Decimal('29.00'), Decimal('12.00'), Decimal('1992.00'), 'SERBIA', None, 'Paul.Taylor@6zHXbuSUIFDAGi.com', '2452362'),
#  (Decimal('45450460.00'), 'AAAAAAAAMNEIFLCA', Decimal('1715357.00'), Decimal('5311.00'), Decimal('25305665.00'), Decimal('2449232.00'), Decimal('2449202.00'), 'Mrs.', 'Michele', 'Medina', 'Y', Decimal('25.00'), Decimal('7.00'), Decimal('1956.00'), 'CAYMAN ISLANDS', None, 'Michele.Medina@hLbx.edu', '2452329'),
#  (Decimal('45450461.00'), 'AAAAAAAANNEIFLCA', Decimal('944702.00'), Decimal('2717.00'), Decimal('1175132.00'), Decimal('2450674.00'), Decimal('2450644.00'), 'Miss', 'Julie', 'Johnson', 'Y', Decimal('26.00'), Decimal('1.00'), Decimal('1927.00'), 'GAMBIA', None, 'Julie.Johnson@EsXkXpEXG0TdHmtvS.org', '2452461'),
#  (Decimal('45450462.00'), 'AAAAAAAAONEIFLCA', Decimal('904092.00'), Decimal('1311.00'), Decimal('12085283.00'), Decimal('2450565.00'), Decimal('2450535.00'), 'Ms.', 'Lynda', 'Morgan', 'Y', Decimal('26.00'), Decimal('8.00'), Decimal('1973.00'), 'NORWAY', None, 'Lynda.Morgan@Bv9ymifu.org', '2452611'),
#  (Decimal('45450463.00'), 'AAAAAAAAPNEIFLCA', Decimal('1300301.00'), Decimal('2475.00'), Decimal('8849096.00'), Decimal('2449227.00'), Decimal('2449197.00'), 'Mr.', 'Christopher', 'Montgomery', 'Y', Decimal('20.00'), Decimal('4.00'), Decimal('1980.00'), 'SWAZILAND', None, 'Christopher.Montgomery@e.org', '2452610'),
#  (Decimal('45450464.00'), 'AAAAAAAAAOEIFLCA', Decimal('282905.00'), Decimal('1221.00'), Decimal('4220784.00'), Decimal('2449662.00'), Decimal('2449632.00'), 'Dr.', 'Michael', 'Shaw', 'Y', Decimal('5.00'), Decimal('6.00'), Decimal('1980.00'), 'BRAZIL', None, 'Michael.Shaw@Z4lXDa9f6b.com', '2452604'),
#  (Decimal('45450465.00'), 'AAAAAAAABOEIFLCA', Decimal('189165.00'), Decimal('3259.00'), Decimal('23114953.00'), Decimal('2452038.00'), Decimal('2452008.00'), 'Mrs.', 'Lucille', 'Cox', 'Y', Decimal('4.00'), Decimal('8.00'), Decimal('1959.00'), 'BARBADOS', None, 'Lucille.Cox@Sg.org', '2452410'),
#  (Decimal('45450466.00'), 'AAAAAAAACOEIFLCA', Decimal('1176402.00'), Decimal('1759.00'), Decimal('1645869.00'), Decimal('2451468.00'), Decimal('2451438.00'), 'Dr.', 'Tyrone', 'Lunn', 'N', Decimal('23.00'), Decimal('2.00'), Decimal('1937.00'), 'ZAMBIA', None, 'Tyrone.Lunn@ZbFVf20YkhIZqA.edu', '2452438'),
#  (Decimal('45450467.00'), 'AAAAAAAADOEIFLCA', Decimal('939200.00'), Decimal('3726.00'), Decimal('29777052.00'), Decimal('2450607.00'), Decimal('2450577.00'), 'Miss', 'Ruth', 'Tolbert', 'Y', Decimal('28.00'), Decimal('11.00'), Decimal('1979.00'), 'IRAQ', None, 'Ruth.Tolbert@hRoIXEUym9F87B5.com', '2452476'),
#  (Decimal('45450468.00'), 'AAAAAAAAEOEIFLCA', None, Decimal('1443.00'), Decimal('29593217.00'), Decimal('2451197.00'), Decimal('2451167.00'), None, 'Joseph', None, 'Y', None, None, None, None, None, 'Joseph.Meadows@8kPlSETYc60.edu', '2452403'),
#  (Decimal('45450469.00'), 'AAAAAAAAFOEIFLCA', Decimal('999258.00'), Decimal('5704.00'), Decimal('10214550.00'), Decimal('2451023.00'), Decimal('2450993.00'), 'Mr.', 'John', 'Kelley', 'N', Decimal('20.00'), Decimal('4.00'), Decimal('1986.00'), 'FRENCH POLYNESIA', None, 'John.Kelley@0dG8yMFSAfstH.edu', '2452368'),
#  (Decimal('45450470.00'), 'AAAAAAAAGOEIFLCA', Decimal('726161.00'), Decimal('3949.00'), Decimal('30307690.00'), Decimal('2452044.00'), Decimal('2452014.00'), 'Mrs.', 'Virginia', 'Jaime', 'N', Decimal('22.00'), Decimal('2.00'), Decimal('1966.00'), 'TOKELAU', None, 'Virginia.Jaime@YJn6toK.edu', '2452429'),
#  (Decimal('45450471.00'), 'AAAAAAAAHOEIFLCA', Decimal('10079.00'), Decimal('4415.00'), Decimal('29170751.00'), Decimal('2452524.00'), Decimal('2452494.00'), 'Dr.', 'Gregory', 'Jackson', 'Y', Decimal('17.00'), Decimal('5.00'), Decimal('1933.00'), 'WESTERN SAHARA', None, 'Gregory.Jackson@zLPx6OlEqd7V.com', '2452557'),
#  (Decimal('45450472.00'), 'AAAAAAAAIOEIFLCA', Decimal('1063590.00'), Decimal('1717.00'), Decimal('21433091.00'), Decimal('2449999.00'), Decimal('2449969.00'), 'Dr.', 'James', 'Brown', 'Y', Decimal('3.00'), Decimal('5.00'), Decimal('1965.00'), 'SEYCHELLES', None, 'James.Brown@M16XDqnvt12DUkV2yN.edu', '2452444'),
#  (Decimal('45450473.00'), 'AAAAAAAAJOEIFLCA', Decimal('748152.00'), Decimal('4216.00'), Decimal('14242680.00'), Decimal('2451431.00'), Decimal('2451401.00'), 'Mr.', 'Jeffrey', 'Hoffman', 'Y', Decimal('16.00'), Decimal('9.00'), Decimal('1961.00'), 'SOMALIA', None, 'Jeffrey.Hoffman@O7KtmxDzVidrLHbgf.com', '2452493'),
#  (Decimal('45450474.00'), 'AAAAAAAAKOEIFLCA', Decimal('925961.00'), Decimal('4028.00'), Decimal('6708848.00'), Decimal('2452113.00'), Decimal('2452083.00'), 'Dr.', 'Marlene', 'Anderson', 'Y', Decimal('16.00'), Decimal('10.00'), Decimal('1928.00'), 'MOROCCO', None, 'Marlene.Anderson@4hXnGscr2Gj5ItQ1xxeO.com', '2452415'),
#  (Decimal('45450475.00'), 'AAAAAAAALOEIFLCA', Decimal('427818.00'), Decimal('5363.00'), Decimal('30317308.00'), Decimal('2449892.00'), Decimal('2449862.00'), 'Mr.', 'Bryce', 'Johnson', 'N', Decimal('10.00'), Decimal('12.00'), Decimal('1952.00'), 'JERSEY', None, 'Bryce.Johnson@CBs.com', '2452586'),
#  (Decimal('45450476.00'), 'AAAAAAAAMOEIFLCA', Decimal('1337043.00'), Decimal('6485.00'), Decimal('26485527.00'), Decimal('2452212.00'), Decimal('2452182.00'), 'Sir', 'James', 'Smith', 'Y', Decimal('7.00'), Decimal('7.00'), Decimal('1927.00'), 'LEBANON', None, 'James.Smith@CxBoN3BPxOjA.edu', '2452562'),
#  (Decimal('45450477.00'), 'AAAAAAAANOEIFLCA', Decimal('887916.00'), Decimal('4914.00'), Decimal('9563959.00'), Decimal('2451351.00'), Decimal('2451321.00'), 'Mrs.', 'Sherrie', 'Kerr', 'N', Decimal('15.00'), Decimal('11.00'), Decimal('1957.00'), 'ALBANIA', None, 'Sherrie.Kerr@OOVHgV9LtAHg.com', '2452506'),
#  (Decimal('45450478.00'), 'AAAAAAAAOOEIFLCA', Decimal('163734.00'), Decimal('4683.00'), Decimal('3333632.00'), Decimal('2452496.00'), Decimal('2452466.00'), 'Sir', 'Douglas', 'Holliman', 'Y', Decimal('24.00'), Decimal('7.00'), Decimal('1968.00'), 'BANGLADESH', None, 'Douglas.Holliman@9NkMxtz0M.com', '2452348'),
#  (Decimal('45450479.00'), 'AAAAAAAAPOEIFLCA', Decimal('1474867.00'), Decimal('2432.00'), Decimal('7892397.00'), Decimal('2449149.00'), Decimal('2449119.00'), 'Dr.', 'Erick', 'Trujillo', 'N', Decimal('11.00'), Decimal('5.00'), Decimal('1940.00'), 'GUYANA', None, 'Erick.Trujillo@MhSqa.org', '2452360'),
#  (Decimal('45450480.00'), 'AAAAAAAAAPEIFLCA', Decimal('1349865.00'), Decimal('434.00'), Decimal('29917850.00'), Decimal('2451547.00'), Decimal('2451517.00'), 'Mrs.', 'Grace', 'Perkins', 'Y', Decimal('27.00'), Decimal('5.00'), Decimal('1959.00'), 'BANGLADESH', None, 'Grace.Perkins@73.edu', '2452507'),
#  (Decimal('45450481.00'), 'AAAAAAAABPEIFLCA', Decimal('1399459.00'), Decimal('1838.00'), Decimal('31024217.00'), Decimal('2452653.00'), Decimal('2452623.00'), 'Dr.', 'Lucy', 'Little', 'Y', Decimal('28.00'), Decimal('9.00'), Decimal('1973.00'), 'HAITI', None, 'Lucy.Little@xId.org', '2452484'),
#  (Decimal('45450482.00'), 'AAAAAAAACPEIFLCA', Decimal('992678.00'), Decimal('1894.00'), Decimal('19535110.00'), Decimal('2449979.00'), Decimal('2449949.00'), 'Sir', 'Maurice', 'Luna', 'Y', Decimal('15.00'), Decimal('12.00'), Decimal('1925.00'), 'GUINEA-BISSAU', None, 'Maurice.Luna@XUnHuLC1av.org', '2452300'),
#  (Decimal('45450483.00'), 'AAAAAAAADPEIFLCA', Decimal('1837280.00'), Decimal('4614.00'), Decimal('32198701.00'), Decimal('2452601.00'), Decimal('2452571.00'), 'Ms.', 'Renee', 'Drummond', 'N', Decimal('25.00'), Decimal('1.00'), Decimal('1966.00'), 'BAHRAIN', None, 'Renee.Drummond@3jjBja.edu', '2452321'),
#  (Decimal('45450484.00'), 'AAAAAAAAEPEIFLCA', Decimal('1158767.00'), Decimal('4836.00'), Decimal('12558552.00'), Decimal('2452398.00'), Decimal('2452368.00'), 'Ms.', 'Colette', 'Johnson', 'Y', Decimal('23.00'), Decimal('4.00'), Decimal('1957.00'), 'SEYCHELLES', None, 'Colette.Johnson@e4kGd5NJxDa9o00d.org', '2452426'),
#  (Decimal('45450485.00'), 'AAAAAAAAFPEIFLCA', Decimal('1122144.00'), Decimal('5823.00'), Decimal('31334302.00'), Decimal('2449918.00'), Decimal('2449888.00'), 'Sir', 'Shaun', 'Meehan', 'N', Decimal('18.00'), Decimal('3.00'), Decimal('1946.00'), 'MALDIVES', None, 'Shaun.Meehan@4sidXqLd9.com', '2452479')]

# %% [markdown]
# #### Step 5: Update the AWS Iceberg table
# NOTE: Run the cell below to generate instructions

# %%
from IPython.display import Markdown as md

here = """
<u>Instructions</u>:
1. In the AWS CE-Sandbox Console, navigate to the [AWS Athena query editor](https://us-west-2.console.aws.amazon.com/athena/home?region=us-west-2#/query-editor) in <code>us-west-2</code>
2. Execute the following SQL to insert additional records into the AWS Iceberg table:
```
insert into {db_name}.{table_name} (select * from {source_table} except select * from {db_name}.{table_name} limit 1000);
```
""".format(db_name=TARGET_DB_NAME, table_name=TARGET_TABLE_NAME, source_table=SOURCE_TABLE)

md(here)
# Out:
# <u>Instructions</u>:
# 1. In the AWS CE-Sandbox Console, navigate to the [AWS Athena query editor](https://us-west-2.console.aws.amazon.com/athena/home?region=us-west-2#/query-editor) in <code>us-west-2</code>
# 2. Execute the following SQL to insert additional records into the AWS Iceberg table:
# ```
# insert into jramizares_db.iceberg_tpcds_sf10tcl_web_sales_t (select * from kterada_db.kt_glue_iceberg_tpcds_sf10tcl_web_sales except select * from jramizares_db.iceberg_tpcds_sf10tcl_web_sales_t limit 1000);
# ```

# %% [markdown]
# #### Step 6: Manually refresh the unmanaged Snowflake Iceberg table
#
# References:
# - Snowflake Documentation: [Manage an Iceberg table](https://docs.snowflake.com/user-guide/tables-iceberg-manage)

# %%
# Replace <MY_UPDATED_OS_ICEBERG_TABLE_METADATA_FILENAME> with the full name of AWS Iceberg table metadata filename in the 
# iceberg_feature_lab/tpcds_sf10tcl/web_sales/ path of your us-west-2 bucket (HINT: Filter for the most current timestamp)
MY_UPDATED_OS_ICEBERG_TABLE_METADATA_FILENAME='00001-82d37e99-4595-4999-a650-8c59581840c5.metadata.json'

# %%
# %%sql
#
# alter iceberg table {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t refresh 'iceberg_feature_lab/tpcds_sf10tcl/web_sales/metadata/{MY_UPDATED_OS_ICEBERG_TABLE_METADATA_FILENAME}';
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# [('Statement executed successfully.',)]

# %%
# %%sql
#
# use role support_rl;
# use warehouse {SNOW_USER}_wh;
# select
#     *
# from {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t
# where true
# limit 100
# ;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 100 rows affected.
# [(Decimal('45450322.00'), 'AAAAAAAACFEIFLCA', Decimal('107525.00'), Decimal('4348.00'), Decimal('20190771.00'), Decimal('2451698.00'), Decimal('2451668.00'), 'Dr.', 'Clyde', 'Johnson', 'N', Decimal('18.00'), Decimal('7.00'), Decimal('1967.00'), 'BELGIUM', None, 'Clyde.Johnson@05T4omXCqE8o0AR.com', '2452332'),
#  (Decimal('45450323.00'), 'AAAAAAAADFEIFLCA', Decimal('555423.00'), Decimal('5126.00'), Decimal('13787182.00'), Decimal('2449772.00'), Decimal('2449742.00'), 'Dr.', 'Todd', 'Jones', 'Y', Decimal('19.00'), Decimal('5.00'), Decimal('1956.00'), 'GEORGIA', None, 'Todd.Jones@qpfFzHa25n.org', '2452393'),
#  (Decimal('45450324.00'), 'AAAAAAAAEFEIFLCA', Decimal('1081796.00'), Decimal('1018.00'), Decimal('2803887.00'), Decimal('2451086.00'), Decimal('2451056.00'), 'Ms.', 'Jessica', 'Wilson', 'N', Decimal('30.00'), Decimal('9.00'), Decimal('1986.00'), 'RÉUNION', None, 'Jessica.Wilson@1aejCR8S.org', '2452568'),
#  (Decimal('45450325.00'), 'AAAAAAAAFFEIFLCA', Decimal('1464097.00'), Decimal('1919.00'), Decimal('28482141.00'), Decimal('2451805.00'), Decimal('2451775.00'), 'Mr.', 'Christopher', 'Jones', 'N', Decimal('2.00'), Decimal('8.00'), Decimal('1985.00'), 'GEORGIA', None, 'Christopher.Jones@udEI.edu', '2452366'),
#  (Decimal('45450326.00'), 'AAAAAAAAGFEIFLCA', Decimal('474105.00'), Decimal('4926.00'), Decimal('7957347.00'), Decimal('2451823.00'), Decimal('2451793.00'), 'Dr.', 'Casey', 'Osborne', 'Y', Decimal('24.00'), Decimal('3.00'), Decimal('1939.00'), 'PALAU', None, 'Casey.Osborne@OLVka4Ni1p59S.org', '2452450'),
#  (Decimal('45450327.00'), 'AAAAAAAAHFEIFLCA', Decimal('632578.00'), Decimal('6310.00'), Decimal('2191242.00'), Decimal('2452420.00'), Decimal('2452390.00'), 'Dr.', 'Matthew', 'Brooks', 'N', Decimal('25.00'), Decimal('2.00'), Decimal('1991.00'), 'NETHERLANDS', None, 'Matthew.Brooks@B1MYXymcYbErv.com', '2452482'),
#  (Decimal('45450328.00'), 'AAAAAAAAIFEIFLCA', Decimal('164121.00'), Decimal('4655.00'), Decimal('24795589.00'), Decimal('2449413.00'), Decimal('2449383.00'), 'Sir', 'Larry', 'Martin', 'Y', Decimal('23.00'), Decimal('8.00'), Decimal('1984.00'), 'BELIZE', None, 'Larry.Martin@VrQnhjd.com', '2452365'),
#  (Decimal('45450329.00'), 'AAAAAAAAJFEIFLCA', Decimal('932262.00'), Decimal('3572.00'), Decimal('24018082.00'), Decimal('2452204.00'), Decimal('2452174.00'), 'Ms.', 'Jeanette', 'White', 'Y', Decimal('29.00'), Decimal('9.00'), Decimal('1937.00'), 'BELARUS', None, 'Jeanette.White@FSuX8TE.com', '2452445'),
#  (Decimal('45450330.00'), 'AAAAAAAAKFEIFLCA', Decimal('68098.00'), Decimal('101.00'), Decimal('28172104.00'), Decimal('2450779.00'), Decimal('2450749.00'), 'Dr.', 'Christy', 'Collins', 'Y', Decimal('25.00'), Decimal('3.00'), Decimal('1949.00'), 'ARUBA', None, 'Christy.Collins@yonCligsyhQ.org', '2452496'),
#  (Decimal('45450331.00'), 'AAAAAAAALFEIFLCA', Decimal('917761.00'), Decimal('2710.00'), Decimal('5456459.00'), Decimal('2451188.00'), Decimal('2451158.00'), 'Mr.', 'Michael', 'Alvarado', 'Y', Decimal('4.00'), Decimal('2.00'), Decimal('1940.00'), 'HONDURAS', None, 'Michael.Alvarado@QeRVi8VKA.edu', '2452356'),
#  (Decimal('45450332.00'), 'AAAAAAAAMFEIFLCA', Decimal('706994.00'), Decimal('6199.00'), Decimal('26455804.00'), Decimal('2452310.00'), Decimal('2452280.00'), 'Ms.', 'Edna', 'Wilson', 'N', Decimal('15.00'), Decimal('1.00'), Decimal('1941.00'), 'BURKINA FASO', None, 'Edna.Wilson@txYllpBQVG0h.edu', '2452290'),
#  (Decimal('45450333.00'), 'AAAAAAAANFEIFLCA', Decimal('413898.00'), Decimal('5113.00'), Decimal('30061128.00'), Decimal('2449294.00'), Decimal('2449264.00'), 'Sir', 'Royce', 'Jacobs', 'Y', Decimal('4.00'), Decimal('4.00'), Decimal('1928.00'), 'MOZAMBIQUE', None, 'Royce.Jacobs@6AncUR.edu', '2452595'),
#  (Decimal('45450334.00'), 'AAAAAAAAOFEIFLCA', Decimal('1223787.00'), Decimal('2275.00'), Decimal('31613916.00'), Decimal('2451156.00'), Decimal('2451126.00'), 'Mrs.', 'Angel', 'Williamson', 'Y', Decimal('27.00'), Decimal('3.00'), Decimal('1933.00'), 'CHILE', None, 'Angel.Williamson@9.edu', '2452310'),
#  (Decimal('45450335.00'), 'AAAAAAAAPFEIFLCA', Decimal('1683934.00'), Decimal('4552.00'), Decimal('23949970.00'), Decimal('2452658.00'), Decimal('2452628.00'), 'Mr.', 'Cesar', 'Ragland', 'Y', Decimal('29.00'), Decimal('9.00'), Decimal('1958.00'), 'TIMOR-LESTE', None, 'Cesar.Ragland@pJJbpDn2tlzO.com', '2452549'),
#  (Decimal('45450336.00'), 'AAAAAAAAAGEIFLCA', Decimal('334845.00'), Decimal('5863.00'), Decimal('29750128.00'), Decimal('2449452.00'), Decimal('2449422.00'), 'Sir', 'Tobias', 'Lee', 'N', Decimal('19.00'), Decimal('5.00'), Decimal('1947.00'), 'BRAZIL', None, 'Tobias.Lee@aZr3cl6V4OVMKcyan.com', '2452372'),
#  (Decimal('45450337.00'), 'AAAAAAAABGEIFLCA', Decimal('203387.00'), Decimal('5929.00'), Decimal('22110518.00'), Decimal('2451861.00'), Decimal('2451831.00'), 'Sir', 'James', 'James', 'N', Decimal('9.00'), Decimal('1.00'), Decimal('1969.00'), 'GUADELOUPE', None, 'James.James@bhl.org', '2452454'),
#  (Decimal('45450338.00'), 'AAAAAAAACGEIFLCA', Decimal('360235.00'), Decimal('5513.00'), Decimal('11396744.00'), Decimal('2450668.00'), Decimal('2450638.00'), 'Mrs.', 'Sylvia', 'Staley', 'N', Decimal('29.00'), Decimal('7.00'), Decimal('1970.00'), 'TAJIKISTAN', None, 'Sylvia.Staley@vQqLoLsdRfAvZc.org', '2452298'),
#  (Decimal('45450339.00'), 'AAAAAAAADGEIFLCA', Decimal('810820.00'), Decimal('406.00'), Decimal('23856392.00'), Decimal('2449729.00'), Decimal('2449699.00'), 'Miss', 'Joyce', 'Smithson', 'Y', Decimal('27.00'), Decimal('8.00'), Decimal('1973.00'), 'LATVIA', None, 'Joyce.Smithson@KVNiXRGx41S.com', '2452406'),
#  (Decimal('45450340.00'), 'AAAAAAAAEGEIFLCA', Decimal('34841.00'), Decimal('814.00'), Decimal('4581634.00'), Decimal('2451471.00'), Decimal('2451441.00'), 'Sir', 'John', 'Roberts', 'Y', Decimal('18.00'), Decimal('7.00'), Decimal('1952.00'), 'GAMBIA', None, 'John.Roberts@C3LaRJ9U.edu', '2452337'),
#  (Decimal('45450341.00'), 'AAAAAAAAFGEIFLCA', Decimal('855130.00'), Decimal('5193.00'), Decimal('8725656.00'), Decimal('2451524.00'), Decimal('2451494.00'), 'Mr.', 'Roland', 'Miller', 'Y', Decimal('21.00'), Decimal('7.00'), Decimal('1964.00'), 'NIUE', None, 'Roland.Miller@Cca9.edu', '2452520'),
#  (Decimal('45450342.00'), 'AAAAAAAAGGEIFLCA', Decimal('198008.00'), Decimal('4476.00'), Decimal('14826591.00'), Decimal('2451941.00'), Decimal('2451911.00'), 'Mrs.', 'Gladys', 'Bennett', 'N', Decimal('23.00'), Decimal('6.00'), Decimal('1946.00'), 'GUADELOUPE', None, 'Gladys.Bennett@hOdm.com', '2452451'),
#  (Decimal('45450343.00'), 'AAAAAAAAHGEIFLCA', Decimal('1223806.00'), Decimal('3100.00'), Decimal('378841.00'), Decimal('2450859.00'), Decimal('2450829.00'), 'Sir', 'Jonathan', 'Gamble', 'Y', Decimal('19.00'), Decimal('5.00'), Decimal('1956.00'), 'TUNISIA', None, 'Jonathan.Gamble@uEJKHscP0h5D1HIm.org', '2452578'),
#  (Decimal('45450344.00'), 'AAAAAAAAIGEIFLCA', Decimal('1089724.00'), Decimal('1783.00'), Decimal('1821395.00'), Decimal('2449819.00'), Decimal('2449789.00'), 'Mrs.', 'Ciara', 'Gould', 'Y', Decimal('12.00'), Decimal('3.00'), Decimal('1978.00'), 'MAYOTTE', None, 'Ciara.Gould@OG1i8818ftY98.org', '2452506'),
#  (Decimal('45450345.00'), 'AAAAAAAAJGEIFLCA', Decimal('879643.00'), Decimal('1127.00'), Decimal('28938258.00'), Decimal('2449201.00'), Decimal('2449171.00'), 'Miss', 'Evelyn', 'Jordan', 'Y', Decimal('5.00'), Decimal('9.00'), Decimal('1990.00'), 'IRAQ', None, 'Evelyn.Jordan@oDA7VevqFrSl4VbflZG.edu', '2452380'),
#  (Decimal('45450346.00'), 'AAAAAAAAKGEIFLCA', Decimal('47729.00'), Decimal('466.00'), Decimal('8521650.00'), Decimal('2451318.00'), Decimal('2451288.00'), 'Mr.', 'Allan', 'Williams', 'N', Decimal('9.00'), Decimal('5.00'), Decimal('1961.00'), 'FAROE ISLANDS', None, 'Allan.Williams@qxGVE.com', '2452598'),
#  (Decimal('45450347.00'), 'AAAAAAAALGEIFLCA', Decimal('1554458.00'), Decimal('2070.00'), Decimal('25644529.00'), Decimal('2452320.00'), Decimal('2452290.00'), 'Dr.', 'John', 'Nielsen', 'N', Decimal('12.00'), Decimal('1.00'), Decimal('1925.00'), 'TIMOR-LESTE', None, 'John.Nielsen@X9yso3.org', '2452540'),
#  (Decimal('45450348.00'), 'AAAAAAAAMGEIFLCA', Decimal('1419938.00'), Decimal('6897.00'), Decimal('3943456.00'), Decimal('2452082.00'), Decimal('2452052.00'), 'Dr.', 'Gregory', 'Rogers', 'Y', Decimal('14.00'), Decimal('11.00'), Decimal('1960.00'), 'GERMANY', None, 'Gregory.Rogers@KE.com', '2452498'),
#  (Decimal('45450349.00'), 'AAAAAAAANGEIFLCA', Decimal('1030208.00'), Decimal('5154.00'), Decimal('9718147.00'), Decimal('2451237.00'), Decimal('2451207.00'), 'Dr.', 'Alice', 'Cordero', 'Y', Decimal('22.00'), Decimal('2.00'), Decimal('1936.00'), 'ARMENIA', None, 'Alice.Cordero@qkPpMs0QBsaQg2gj3.com', '2452386'),
#  (Decimal('45450350.00'), 'AAAAAAAAOGEIFLCA', Decimal('1638059.00'), Decimal('1096.00'), Decimal('13873380.00'), Decimal('2450536.00'), Decimal('2450506.00'), 'Ms.', 'Linda', 'Mccarthy', 'N', Decimal('18.00'), Decimal('1.00'), Decimal('1975.00'), 'NIGERIA', None, 'Linda.Mccarthy@vTdr1Tets756Rb.com', '2452544'),
#  (Decimal('45450351.00'), 'AAAAAAAAPGEIFLCA', Decimal('805603.00'), Decimal('6149.00'), Decimal('2925448.00'), Decimal('2451725.00'), Decimal('2451695.00'), 'Dr.', 'Rebecca', 'Goodman', 'N', Decimal('28.00'), Decimal('2.00'), Decimal('1967.00'), 'MONACO', None, 'Rebecca.Goodman@Mkf2glt4B323B.com', '2452533'),
#  (Decimal('45450352.00'), 'AAAAAAAAAHEIFLCA', Decimal('991270.00'), Decimal('1676.00'), Decimal('1580529.00'), Decimal('2449858.00'), Decimal('2449828.00'), 'Sir', 'Keith', 'Reed', 'N', Decimal('19.00'), Decimal('10.00'), Decimal('1927.00'), 'HONG KONG', None, 'Keith.Reed@sG9B0HEa.edu', '2452549'),
#  (Decimal('45450353.00'), 'AAAAAAAABHEIFLCA', Decimal('637074.00'), Decimal('839.00'), Decimal('19539804.00'), Decimal('2450907.00'), Decimal('2450877.00'), 'Sir', 'Earl', 'Young', 'N', Decimal('15.00'), Decimal('6.00'), Decimal('1977.00'), 'YEMEN', None, 'Earl.Young@lzTXKGhshty3yCg6.edu', '2452359'),
#  (Decimal('45450354.00'), 'AAAAAAAACHEIFLCA', Decimal('399977.00'), Decimal('3737.00'), Decimal('29420744.00'), Decimal('2449555.00'), Decimal('2449525.00'), 'Sir', 'David', 'Holmes', 'N', Decimal('15.00'), Decimal('8.00'), Decimal('1986.00'), 'SOMALIA', None, 'David.Holmes@TrbYSjOlzRtBQ.org', '2452557'),
#  (Decimal('45450355.00'), 'AAAAAAAADHEIFLCA', Decimal('405437.00'), Decimal('1481.00'), Decimal('25251925.00'), Decimal('2452068.00'), Decimal('2452038.00'), 'Dr.', 'Roy', 'Vigil', 'N', Decimal('24.00'), Decimal('10.00'), Decimal('1961.00'), 'SLOVENIA', None, 'Roy.Vigil@76.org', '2452318'),
#  (Decimal('45450356.00'), 'AAAAAAAAEHEIFLCA', Decimal('747889.00'), Decimal('4461.00'), Decimal('12830986.00'), Decimal('2450138.00'), Decimal('2450108.00'), 'Dr.', 'Nathan', 'Nelms', 'N', Decimal('23.00'), Decimal('9.00'), Decimal('1989.00'), 'MONACO', None, 'Nathan.Nelms@ee.edu', '2452446'),
#  (Decimal('45450357.00'), 'AAAAAAAAFHEIFLCA', Decimal('1373188.00'), Decimal('2386.00'), Decimal('3511584.00'), Decimal('2450276.00'), Decimal('2450246.00'), 'Ms.', 'Charlotte', 'Edmondson', 'N', Decimal('21.00'), Decimal('5.00'), Decimal('1946.00'), 'MONTSERRAT', None, 'Charlotte.Edmondson@y7x6NKUBjuG.org', '2452344'),
#  (Decimal('45450358.00'), 'AAAAAAAAGHEIFLCA', Decimal('914690.00'), Decimal('4045.00'), Decimal('1981047.00'), Decimal('2450559.00'), Decimal('2450529.00'), 'Dr.', 'Margaret', 'Mcgee', 'N', Decimal('7.00'), Decimal('11.00'), Decimal('1939.00'), 'GHANA', None, 'Margaret.Mcgee@ta2CsLmVvUr.org', '2452283'),
#  (Decimal('45450359.00'), 'AAAAAAAAHHEIFLCA', Decimal('110101.00'), Decimal('3726.00'), Decimal('2748551.00'), Decimal('2451967.00'), Decimal('2451937.00'), 'Miss', 'Ann', 'Mcdonald', 'N', Decimal('6.00'), Decimal('6.00'), Decimal('1952.00'), 'HONG KONG', None, 'Ann.Mcdonald@gvUFDDY.org', '2452491'),
#  (Decimal('45450360.00'), 'AAAAAAAAIHEIFLCA', None, None, Decimal('1456412.00'), Decimal('2451811.00'), None, None, 'Edith', 'Garrett', None, None, Decimal('1.00'), Decimal('1932.00'), 'TIMOR-LESTE', None, 'Edith.Garrett@vDNtklzb3Uh.org', None),
#  (Decimal('45450361.00'), 'AAAAAAAAJHEIFLCA', Decimal('389886.00'), Decimal('4148.00'), Decimal('32113610.00'), Decimal('2449789.00'), Decimal('2449759.00'), 'Mrs.', 'Michelle', 'Soto', 'Y', Decimal('5.00'), Decimal('5.00'), Decimal('1929.00'), 'SOLOMON ISLANDS', None, 'Michelle.Soto@uogm.com', '2452484'),
#  (Decimal('45450362.00'), 'AAAAAAAAKHEIFLCA', Decimal('97183.00'), Decimal('4772.00'), Decimal('5786761.00'), Decimal('2450476.00'), Decimal('2450446.00'), 'Dr.', 'Derrick', 'Shorter', 'N', Decimal('29.00'), Decimal('12.00'), Decimal('1937.00'), 'GUINEA', None, 'Derrick.Shorter@CYBFg.org', '2452523'),
#  (Decimal('45450363.00'), 'AAAAAAAALHEIFLCA', Decimal('321383.00'), Decimal('4504.00'), Decimal('22021578.00'), Decimal('2449941.00'), Decimal('2449911.00'), 'Dr.', 'James', 'Chambers', 'N', Decimal('2.00'), Decimal('1.00'), Decimal('1963.00'), 'ANTIGUA AND BARBUDA', None, 'James.Chambers@FMkB9syMCc.org', '2452372'),
#  (Decimal('45450364.00'), 'AAAAAAAAMHEIFLCA', Decimal('844690.00'), Decimal('4348.00'), Decimal('122406.00'), Decimal('2449940.00'), Decimal('2449910.00'), 'Mr.', 'Charles', 'Morales', 'N', Decimal('14.00'), Decimal('8.00'), Decimal('1933.00'), 'VIET NAM', None, 'Charles.Morales@IFxP.org', '2452358'),
#  (Decimal('45450365.00'), 'AAAAAAAANHEIFLCA', Decimal('282314.00'), Decimal('2793.00'), Decimal('1175272.00'), Decimal('2450974.00'), Decimal('2450944.00'), 'Mr.', 'Ralph', 'Stewart', 'N', Decimal('4.00'), Decimal('6.00'), Decimal('1954.00'), 'BERMUDA', None, 'Ralph.Stewart@Kz1AojFnMz.org', '2452352'),
#  (Decimal('45450366.00'), 'AAAAAAAAOHEIFLCA', Decimal('1606025.00'), Decimal('5497.00'), Decimal('8682569.00'), Decimal('2449449.00'), Decimal('2449419.00'), 'Dr.', 'Angela', 'Mckay', 'N', Decimal('10.00'), Decimal('3.00'), Decimal('1975.00'), 'FRANCE', None, 'Angela.Mckay@skxutB.org', '2452335'),
#  (Decimal('45450367.00'), 'AAAAAAAAPHEIFLCA', Decimal('748014.00'), Decimal('1422.00'), Decimal('14794383.00'), Decimal('2450086.00'), Decimal('2450056.00'), 'Miss', 'Brittany', 'Rivera', 'N', Decimal('26.00'), Decimal('12.00'), Decimal('1948.00'), 'UNITED ARAB EMIRATES', None, 'Brittany.Rivera@leX.edu', '2452557'),
#  (Decimal('45450368.00'), 'AAAAAAAAAIEIFLCA', Decimal('1507583.00'), Decimal('623.00'), Decimal('24013663.00'), Decimal('2450915.00'), Decimal('2450885.00'), 'Ms.', 'Elizabeth', 'Orton', 'N', Decimal('20.00'), Decimal('1.00'), Decimal('1929.00'), 'JERSEY', None, 'Elizabeth.Orton@tTQZ7POGFkju.com', '2452642'),
#  (Decimal('45450369.00'), 'AAAAAAAABIEIFLCA', Decimal('1060054.00'), Decimal('3100.00'), Decimal('29521699.00'), Decimal('2451810.00'), Decimal('2451780.00'), 'Sir', 'Gabriel', 'Nagel', 'N', Decimal('4.00'), Decimal('2.00'), Decimal('1956.00'), 'EL SALVADOR', None, 'Gabriel.Nagel@EJY9mBC.com', '2452643'),
#  (Decimal('45450370.00'), 'AAAAAAAACIEIFLCA', Decimal('658409.00'), Decimal('221.00'), Decimal('3120880.00'), Decimal('2451717.00'), Decimal('2451687.00'), 'Dr.', 'Jorge', 'Burns', 'N', Decimal('14.00'), Decimal('12.00'), Decimal('1989.00'), 'PARAGUAY', None, 'Jorge.Burns@qQa2D0mrYsSfds.edu', '2452617'),
#  (Decimal('45450371.00'), 'AAAAAAAADIEIFLCA', Decimal('1722601.00'), Decimal('4023.00'), Decimal('21216198.00'), Decimal('2451485.00'), Decimal('2451455.00'), 'Ms.', 'Elaine', 'Ryan', 'Y', Decimal('2.00'), Decimal('1.00'), Decimal('1964.00'), 'PHILIPPINES', None, 'Elaine.Ryan@K28mYmuDEVmT.org', '2452416'),
#  (Decimal('45450372.00'), 'AAAAAAAAEIEIFLCA', Decimal('1764934.00'), Decimal('1966.00'), Decimal('1434645.00'), Decimal('2449298.00'), Decimal('2449268.00'), 'Sir', 'Oscar', 'Martinson', 'Y', Decimal('5.00'), Decimal('8.00'), Decimal('1964.00'), 'GUADELOUPE', None, 'Oscar.Martinson@kYQC02SoE25Qu.org', '2452433'),
#  (Decimal('45450373.00'), 'AAAAAAAAFIEIFLCA', Decimal('1877134.00'), Decimal('5289.00'), Decimal('16184997.00'), Decimal('2452643.00'), Decimal('2452613.00'), 'Sir', 'David', 'Levine', 'N', Decimal('7.00'), Decimal('8.00'), Decimal('1989.00'), 'ETHIOPIA', None, 'David.Levine@G2umIkS.com', '2452318'),
#  (Decimal('45450374.00'), 'AAAAAAAAGIEIFLCA', Decimal('1520677.00'), Decimal('4065.00'), Decimal('29822300.00'), Decimal('2452623.00'), Decimal('2452593.00'), 'Dr.', 'Marlene', 'Amaya', 'N', Decimal('20.00'), Decimal('4.00'), Decimal('1984.00'), 'SAUDI ARABIA', None, 'Marlene.Amaya@Z7j7D.org', '2452318'),
#  (Decimal('45450375.00'), 'AAAAAAAAHIEIFLCA', Decimal('1882455.00'), Decimal('6663.00'), Decimal('25309271.00'), Decimal('2452101.00'), Decimal('2452071.00'), 'Mr.', 'Joshua', 'Pacheco', 'Y', Decimal('9.00'), Decimal('6.00'), Decimal('1925.00'), 'AFGHANISTAN', None, 'Joshua.Pacheco@rhcJ5.org', '2452431'),
#  (Decimal('45450376.00'), 'AAAAAAAAIIEIFLCA', None, None, Decimal('27446224.00'), None, None, 'Mr.', 'Clyde', None, None, Decimal('28.00'), None, Decimal('1930.00'), 'HONDURAS', None, None, None),
#  (Decimal('45450377.00'), 'AAAAAAAAJIEIFLCA', Decimal('179680.00'), Decimal('6610.00'), Decimal('28583940.00'), Decimal('2450265.00'), Decimal('2450235.00'), 'Mr.', 'Ira', 'Duncan', 'N', Decimal('18.00'), Decimal('4.00'), Decimal('1967.00'), 'MONTENEGRO', None, 'Ira.Duncan@ryn7Fk7.edu', '2452396'),
#  (Decimal('45450378.00'), 'AAAAAAAAKIEIFLCA', Decimal('1719037.00'), Decimal('1865.00'), Decimal('26409493.00'), Decimal('2452503.00'), Decimal('2452473.00'), 'Ms.', 'Sandra', 'Chapman', 'Y', Decimal('20.00'), Decimal('11.00'), Decimal('1929.00'), 'SOMALIA', None, 'Sandra.Chapman@C7.org', '2452301'),
#  (Decimal('45450379.00'), 'AAAAAAAALIEIFLCA', Decimal('1586943.00'), None, Decimal('14047216.00'), Decimal('2451416.00'), Decimal('2451386.00'), 'Sir', 'James', 'Trujillo', 'Y', Decimal('3.00'), Decimal('4.00'), Decimal('1942.00'), None, None, 'James.Trujillo@6XTuItHsA.edu', None),
#  (Decimal('45450380.00'), 'AAAAAAAAMIEIFLCA', None, Decimal('1655.00'), Decimal('29949676.00'), Decimal('2452461.00'), None, None, 'Sun', None, 'Y', Decimal('1.00'), None, None, None, None, None, None),
#  (Decimal('45450381.00'), 'AAAAAAAANIEIFLCA', Decimal('414587.00'), Decimal('5714.00'), Decimal('31980394.00'), Decimal('2449939.00'), Decimal('2449909.00'), 'Mrs.', 'Sarah', 'Johnson', 'N', Decimal('19.00'), Decimal('2.00'), Decimal('1965.00'), 'TONGA', None, 'Sarah.Johnson@KqS0R5KXocF.org', '2452500'),
#  (Decimal('45450382.00'), 'AAAAAAAAOIEIFLCA', Decimal('895573.00'), Decimal('3651.00'), Decimal('7542129.00'), Decimal('2451554.00'), Decimal('2451524.00'), 'Dr.', 'Jonathan', 'Boyd', 'Y', Decimal('24.00'), Decimal('2.00'), Decimal('1960.00'), 'CHRISTMAS ISLAND', None, 'Jonathan.Boyd@PHNBhsznPp.org', '2452414'),
#  (Decimal('45450383.00'), 'AAAAAAAAPIEIFLCA', Decimal('98655.00'), Decimal('5706.00'), Decimal('22243157.00'), Decimal('2450375.00'), Decimal('2450345.00'), 'Dr.', 'Angelica', 'Black', 'N', Decimal('8.00'), Decimal('10.00'), Decimal('1973.00'), 'NETHERLANDS', None, 'Angelica.Black@NXNRoRoJJ4lxZ.edu', '2452447'),
#  (Decimal('45450384.00'), 'AAAAAAAAAJEIFLCA', Decimal('401358.00'), Decimal('3844.00'), Decimal('2721977.00'), Decimal('2451902.00'), Decimal('2451872.00'), 'Mr.', 'Kenneth', 'Tavares', 'N', Decimal('13.00'), Decimal('10.00'), Decimal('1935.00'), 'BRAZIL', None, 'Kenneth.Tavares@afI3.com', '2452385'),
#  (Decimal('45450449.00'), 'AAAAAAAABNEIFLCA', Decimal('620343.00'), Decimal('919.00'), Decimal('32390295.00'), None, None, 'Sir', 'Paul', None, 'Y', None, Decimal('12.00'), None, 'ANGUILLA', None, 'Paul.Billingsley@XjGpnNOp.edu', '2452287'),
#  (Decimal('45450450.00'), 'AAAAAAAACNEIFLCA', Decimal('1910231.00'), Decimal('2657.00'), Decimal('10808683.00'), Decimal('2451883.00'), Decimal('2451853.00'), 'Mr.', 'Howard', 'Tate', 'Y', Decimal('9.00'), Decimal('3.00'), Decimal('1973.00'), 'INDONESIA', None, 'Howard.Tate@CL7nYT0JiSp.org', '2452402'),
#  (Decimal('45450451.00'), 'AAAAAAAADNEIFLCA', Decimal('1792257.00'), Decimal('4559.00'), Decimal('7772414.00'), Decimal('2451434.00'), Decimal('2451404.00'), 'Dr.', 'Meagan', 'Wood', 'N', Decimal('12.00'), Decimal('4.00'), Decimal('1953.00'), 'SAINT HELENA', None, 'Meagan.Wood@uuuoyI.org', '2452455'),
#  (Decimal('45450452.00'), 'AAAAAAAAENEIFLCA', Decimal('79693.00'), Decimal('90.00'), Decimal('11096487.00'), Decimal('2452319.00'), Decimal('2452289.00'), 'Mrs.', 'Dorothy', 'Trotter', 'N', Decimal('28.00'), Decimal('9.00'), Decimal('1961.00'), 'NICARAGUA', None, 'Dorothy.Trotter@cC9gyOV4pTxy.com', '2452392'),
#  (Decimal('45450453.00'), 'AAAAAAAAFNEIFLCA', Decimal('738270.00'), None, Decimal('17472270.00'), None, Decimal('2451438.00'), 'Dr.', 'Juanita', None, None, Decimal('25.00'), None, None, None, None, 'Juanita.Andrews@kgU21ALl9X.com', None),
#  (Decimal('45450454.00'), 'AAAAAAAAGNEIFLCA', Decimal('1197257.00'), Decimal('4352.00'), Decimal('21927447.00'), Decimal('2452650.00'), Decimal('2452620.00'), 'Mr.', 'Shane', 'Brennan', 'Y', Decimal('20.00'), Decimal('5.00'), Decimal('1935.00'), 'EL SALVADOR', None, 'Shane.Brennan@JZ11r4iRu6nQ9.com', '2452433'),
#  (Decimal('45450455.00'), 'AAAAAAAAHNEIFLCA', Decimal('247111.00'), Decimal('855.00'), Decimal('12103046.00'), Decimal('2450019.00'), Decimal('2449989.00'), 'Sir', 'Roy', 'Christian', 'Y', Decimal('2.00'), Decimal('4.00'), Decimal('1945.00'), 'CAPE VERDE', None, 'Roy.Christian@02xhc.org', '2452294'),
#  (Decimal('45450456.00'), 'AAAAAAAAINEIFLCA', Decimal('1229224.00'), Decimal('2264.00'), Decimal('13005257.00'), Decimal('2449667.00'), Decimal('2449637.00'), 'Dr.', 'Tommy', 'Bush', 'N', Decimal('4.00'), Decimal('5.00'), Decimal('1992.00'), 'BERMUDA', None, 'Tommy.Bush@8ayc4mkuUC.com', '2452602'),
#  (Decimal('45450457.00'), 'AAAAAAAAJNEIFLCA', Decimal('1201120.00'), Decimal('4676.00'), Decimal('21722279.00'), Decimal('2452553.00'), Decimal('2452523.00'), 'Dr.', 'Keith', 'Turner', 'N', Decimal('6.00'), Decimal('8.00'), Decimal('1954.00'), 'SAINT HELENA', None, 'Keith.Turner@5THpOOnOpm.edu', '2452404'),
#  (Decimal('45450458.00'), 'AAAAAAAAKNEIFLCA', Decimal('121079.00'), Decimal('3676.00'), Decimal('3737473.00'), Decimal('2451639.00'), Decimal('2451609.00'), 'Dr.', 'Lilia', 'Ackerman', 'Y', Decimal('24.00'), Decimal('10.00'), Decimal('1983.00'), 'PHILIPPINES', None, 'Lilia.Ackerman@bGeEiPPr2sFg6GXj.com', '2452462'),
#  (Decimal('45450459.00'), 'AAAAAAAALNEIFLCA', Decimal('92207.00'), Decimal('5691.00'), Decimal('14399175.00'), Decimal('2449430.00'), Decimal('2449400.00'), 'Sir', 'Paul', 'Taylor', 'N', Decimal('29.00'), Decimal('12.00'), Decimal('1992.00'), 'SERBIA', None, 'Paul.Taylor@6zHXbuSUIFDAGi.com', '2452362'),
#  (Decimal('45450460.00'), 'AAAAAAAAMNEIFLCA', Decimal('1715357.00'), Decimal('5311.00'), Decimal('25305665.00'), Decimal('2449232.00'), Decimal('2449202.00'), 'Mrs.', 'Michele', 'Medina', 'Y', Decimal('25.00'), Decimal('7.00'), Decimal('1956.00'), 'CAYMAN ISLANDS', None, 'Michele.Medina@hLbx.edu', '2452329'),
#  (Decimal('45450461.00'), 'AAAAAAAANNEIFLCA', Decimal('944702.00'), Decimal('2717.00'), Decimal('1175132.00'), Decimal('2450674.00'), Decimal('2450644.00'), 'Miss', 'Julie', 'Johnson', 'Y', Decimal('26.00'), Decimal('1.00'), Decimal('1927.00'), 'GAMBIA', None, 'Julie.Johnson@EsXkXpEXG0TdHmtvS.org', '2452461'),
#  (Decimal('45450462.00'), 'AAAAAAAAONEIFLCA', Decimal('904092.00'), Decimal('1311.00'), Decimal('12085283.00'), Decimal('2450565.00'), Decimal('2450535.00'), 'Ms.', 'Lynda', 'Morgan', 'Y', Decimal('26.00'), Decimal('8.00'), Decimal('1973.00'), 'NORWAY', None, 'Lynda.Morgan@Bv9ymifu.org', '2452611'),
#  (Decimal('45450463.00'), 'AAAAAAAAPNEIFLCA', Decimal('1300301.00'), Decimal('2475.00'), Decimal('8849096.00'), Decimal('2449227.00'), Decimal('2449197.00'), 'Mr.', 'Christopher', 'Montgomery', 'Y', Decimal('20.00'), Decimal('4.00'), Decimal('1980.00'), 'SWAZILAND', None, 'Christopher.Montgomery@e.org', '2452610'),
#  (Decimal('45450464.00'), 'AAAAAAAAAOEIFLCA', Decimal('282905.00'), Decimal('1221.00'), Decimal('4220784.00'), Decimal('2449662.00'), Decimal('2449632.00'), 'Dr.', 'Michael', 'Shaw', 'Y', Decimal('5.00'), Decimal('6.00'), Decimal('1980.00'), 'BRAZIL', None, 'Michael.Shaw@Z4lXDa9f6b.com', '2452604'),
#  (Decimal('45450465.00'), 'AAAAAAAABOEIFLCA', Decimal('189165.00'), Decimal('3259.00'), Decimal('23114953.00'), Decimal('2452038.00'), Decimal('2452008.00'), 'Mrs.', 'Lucille', 'Cox', 'Y', Decimal('4.00'), Decimal('8.00'), Decimal('1959.00'), 'BARBADOS', None, 'Lucille.Cox@Sg.org', '2452410'),
#  (Decimal('45450466.00'), 'AAAAAAAACOEIFLCA', Decimal('1176402.00'), Decimal('1759.00'), Decimal('1645869.00'), Decimal('2451468.00'), Decimal('2451438.00'), 'Dr.', 'Tyrone', 'Lunn', 'N', Decimal('23.00'), Decimal('2.00'), Decimal('1937.00'), 'ZAMBIA', None, 'Tyrone.Lunn@ZbFVf20YkhIZqA.edu', '2452438'),
#  (Decimal('45450467.00'), 'AAAAAAAADOEIFLCA', Decimal('939200.00'), Decimal('3726.00'), Decimal('29777052.00'), Decimal('2450607.00'), Decimal('2450577.00'), 'Miss', 'Ruth', 'Tolbert', 'Y', Decimal('28.00'), Decimal('11.00'), Decimal('1979.00'), 'IRAQ', None, 'Ruth.Tolbert@hRoIXEUym9F87B5.com', '2452476'),
#  (Decimal('45450468.00'), 'AAAAAAAAEOEIFLCA', None, Decimal('1443.00'), Decimal('29593217.00'), Decimal('2451197.00'), Decimal('2451167.00'), None, 'Joseph', None, 'Y', None, None, None, None, None, 'Joseph.Meadows@8kPlSETYc60.edu', '2452403'),
#  (Decimal('45450469.00'), 'AAAAAAAAFOEIFLCA', Decimal('999258.00'), Decimal('5704.00'), Decimal('10214550.00'), Decimal('2451023.00'), Decimal('2450993.00'), 'Mr.', 'John', 'Kelley', 'N', Decimal('20.00'), Decimal('4.00'), Decimal('1986.00'), 'FRENCH POLYNESIA', None, 'John.Kelley@0dG8yMFSAfstH.edu', '2452368'),
#  (Decimal('45450470.00'), 'AAAAAAAAGOEIFLCA', Decimal('726161.00'), Decimal('3949.00'), Decimal('30307690.00'), Decimal('2452044.00'), Decimal('2452014.00'), 'Mrs.', 'Virginia', 'Jaime', 'N', Decimal('22.00'), Decimal('2.00'), Decimal('1966.00'), 'TOKELAU', None, 'Virginia.Jaime@YJn6toK.edu', '2452429'),
#  (Decimal('45450471.00'), 'AAAAAAAAHOEIFLCA', Decimal('10079.00'), Decimal('4415.00'), Decimal('29170751.00'), Decimal('2452524.00'), Decimal('2452494.00'), 'Dr.', 'Gregory', 'Jackson', 'Y', Decimal('17.00'), Decimal('5.00'), Decimal('1933.00'), 'WESTERN SAHARA', None, 'Gregory.Jackson@zLPx6OlEqd7V.com', '2452557'),
#  (Decimal('45450472.00'), 'AAAAAAAAIOEIFLCA', Decimal('1063590.00'), Decimal('1717.00'), Decimal('21433091.00'), Decimal('2449999.00'), Decimal('2449969.00'), 'Dr.', 'James', 'Brown', 'Y', Decimal('3.00'), Decimal('5.00'), Decimal('1965.00'), 'SEYCHELLES', None, 'James.Brown@M16XDqnvt12DUkV2yN.edu', '2452444'),
#  (Decimal('45450473.00'), 'AAAAAAAAJOEIFLCA', Decimal('748152.00'), Decimal('4216.00'), Decimal('14242680.00'), Decimal('2451431.00'), Decimal('2451401.00'), 'Mr.', 'Jeffrey', 'Hoffman', 'Y', Decimal('16.00'), Decimal('9.00'), Decimal('1961.00'), 'SOMALIA', None, 'Jeffrey.Hoffman@O7KtmxDzVidrLHbgf.com', '2452493'),
#  (Decimal('45450474.00'), 'AAAAAAAAKOEIFLCA', Decimal('925961.00'), Decimal('4028.00'), Decimal('6708848.00'), Decimal('2452113.00'), Decimal('2452083.00'), 'Dr.', 'Marlene', 'Anderson', 'Y', Decimal('16.00'), Decimal('10.00'), Decimal('1928.00'), 'MOROCCO', None, 'Marlene.Anderson@4hXnGscr2Gj5ItQ1xxeO.com', '2452415'),
#  (Decimal('45450475.00'), 'AAAAAAAALOEIFLCA', Decimal('427818.00'), Decimal('5363.00'), Decimal('30317308.00'), Decimal('2449892.00'), Decimal('2449862.00'), 'Mr.', 'Bryce', 'Johnson', 'N', Decimal('10.00'), Decimal('12.00'), Decimal('1952.00'), 'JERSEY', None, 'Bryce.Johnson@CBs.com', '2452586'),
#  (Decimal('45450476.00'), 'AAAAAAAAMOEIFLCA', Decimal('1337043.00'), Decimal('6485.00'), Decimal('26485527.00'), Decimal('2452212.00'), Decimal('2452182.00'), 'Sir', 'James', 'Smith', 'Y', Decimal('7.00'), Decimal('7.00'), Decimal('1927.00'), 'LEBANON', None, 'James.Smith@CxBoN3BPxOjA.edu', '2452562'),
#  (Decimal('45450477.00'), 'AAAAAAAANOEIFLCA', Decimal('887916.00'), Decimal('4914.00'), Decimal('9563959.00'), Decimal('2451351.00'), Decimal('2451321.00'), 'Mrs.', 'Sherrie', 'Kerr', 'N', Decimal('15.00'), Decimal('11.00'), Decimal('1957.00'), 'ALBANIA', None, 'Sherrie.Kerr@OOVHgV9LtAHg.com', '2452506'),
#  (Decimal('45450478.00'), 'AAAAAAAAOOEIFLCA', Decimal('163734.00'), Decimal('4683.00'), Decimal('3333632.00'), Decimal('2452496.00'), Decimal('2452466.00'), 'Sir', 'Douglas', 'Holliman', 'Y', Decimal('24.00'), Decimal('7.00'), Decimal('1968.00'), 'BANGLADESH', None, 'Douglas.Holliman@9NkMxtz0M.com', '2452348'),
#  (Decimal('45450479.00'), 'AAAAAAAAPOEIFLCA', Decimal('1474867.00'), Decimal('2432.00'), Decimal('7892397.00'), Decimal('2449149.00'), Decimal('2449119.00'), 'Dr.', 'Erick', 'Trujillo', 'N', Decimal('11.00'), Decimal('5.00'), Decimal('1940.00'), 'GUYANA', None, 'Erick.Trujillo@MhSqa.org', '2452360'),
#  (Decimal('45450480.00'), 'AAAAAAAAAPEIFLCA', Decimal('1349865.00'), Decimal('434.00'), Decimal('29917850.00'), Decimal('2451547.00'), Decimal('2451517.00'), 'Mrs.', 'Grace', 'Perkins', 'Y', Decimal('27.00'), Decimal('5.00'), Decimal('1959.00'), 'BANGLADESH', None, 'Grace.Perkins@73.edu', '2452507'),
#  (Decimal('45450481.00'), 'AAAAAAAABPEIFLCA', Decimal('1399459.00'), Decimal('1838.00'), Decimal('31024217.00'), Decimal('2452653.00'), Decimal('2452623.00'), 'Dr.', 'Lucy', 'Little', 'Y', Decimal('28.00'), Decimal('9.00'), Decimal('1973.00'), 'HAITI', None, 'Lucy.Little@xId.org', '2452484'),
#  (Decimal('45450482.00'), 'AAAAAAAACPEIFLCA', Decimal('992678.00'), Decimal('1894.00'), Decimal('19535110.00'), Decimal('2449979.00'), Decimal('2449949.00'), 'Sir', 'Maurice', 'Luna', 'Y', Decimal('15.00'), Decimal('12.00'), Decimal('1925.00'), 'GUINEA-BISSAU', None, 'Maurice.Luna@XUnHuLC1av.org', '2452300'),
#  (Decimal('45450483.00'), 'AAAAAAAADPEIFLCA', Decimal('1837280.00'), Decimal('4614.00'), Decimal('32198701.00'), Decimal('2452601.00'), Decimal('2452571.00'), 'Ms.', 'Renee', 'Drummond', 'N', Decimal('25.00'), Decimal('1.00'), Decimal('1966.00'), 'BAHRAIN', None, 'Renee.Drummond@3jjBja.edu', '2452321'),
#  (Decimal('45450484.00'), 'AAAAAAAAEPEIFLCA', Decimal('1158767.00'), Decimal('4836.00'), Decimal('12558552.00'), Decimal('2452398.00'), Decimal('2452368.00'), 'Ms.', 'Colette', 'Johnson', 'Y', Decimal('23.00'), Decimal('4.00'), Decimal('1957.00'), 'SEYCHELLES', None, 'Colette.Johnson@e4kGd5NJxDa9o00d.org', '2452426'),
#  (Decimal('45450485.00'), 'AAAAAAAAFPEIFLCA', Decimal('1122144.00'), Decimal('5823.00'), Decimal('31334302.00'), Decimal('2449918.00'), Decimal('2449888.00'), 'Sir', 'Shaun', 'Meehan', 'N', Decimal('18.00'), Decimal('3.00'), Decimal('1946.00'), 'MALDIVES', None, 'Shaun.Meehan@4sidXqLd9.com', '2452479')]

# %%
# %%sql
#
# use role support_rl;
# use warehouse {SNOW_USER}_wh;
# select
#     count(*)
# from {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t
# where true
# ;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [(2000,)]

# %% [markdown]
# ### Exercise 1: Cleanup (Optional)
#
# Execute the cell below to drop the Snowflake objects created in this exercise.

# %%
# %%sql
#
# use role support_rl;
# use {SNOW_USER}_db.iceberg;
# drop iceberg table if exists {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t;
# drop catalog integration if exists {SNOW_USER}_os_iceberg_cat_int;
# drop external volume if exists {SNOW_USER}_os_ext_vol;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [('JRAMIZARES_OS_EXT_VOL successfully dropped.',)]

# %% [markdown]
# ### Exercise 2: Create an unmanaged AWS Iceberg table (type=GLUE)
#
# NOTE: This exercise will use a pre-existing AWS Iceberg table created by AWS Glue

# %% [markdown]
# #### Step 1: Create an IAM role with AWS S3 permissions to the pre-existing AWS Iceberg table
#
# NOTE: Run the cell below to generate instructions

# %%
from IPython.display import Markdown as md

here = """
<u>Instructions</u>:
1. In the AWS CE-Sandbox Console, navigate to **Identity and Access Management (IAM)** > [**Roles**](https://us-east-1.console.aws.amazon.com/iam/home#/roles)
2. Click the **Create role** button
3. On the **Specify permissions page**, click the **JSON** button to toggle to the JSON editor
4. Select **Trusted entity type** > **AWS account**
5. Click the **Next** button
6. On the **Add permissions** page, lookup and click the checkbox for **kterada_custom_s3_policy**
7. Click the **Next** button
8. Name the role **{username}_iceberg_lab_s3_role**
9. Click the **Create role** button
10. Replace `<MY_GLUE_S3_IAM_ROLE_ARN>` with the IAM role ARN in the cell below and execute
""".format(username=SNOW_USER, db_name=TARGET_DB_NAME, table_name=TARGET_TABLE_NAME, source_table=SOURCE_TABLE)

md(here)
# Out:
# <u>Instructions</u>:
# 1. In the AWS CE-Sandbox Console, navigate to **Identity and Access Management (IAM)** > [**Roles**](https://us-east-1.console.aws.amazon.com/iam/home#/roles)
# 2. Click the **Create role** button
# 3. On the **Specify permissions page**, click the **JSON** button to toggle to the JSON editor
# 4. Select **Trusted entity type** > **AWS account**
# 5. Click the **Next** button
# 6. On the **Add permissions** page, lookup and click the checkbox for **kterada_custom_s3_policy**
# 7. Click the **Next** button
# 8. Name the role **jramizares_iceberg_lab_s3_role**
# 9. Click the **Create role** button
# 10. Replace `<MY_GLUE_S3_IAM_ROLE_ARN>` with the IAM role ARN in the cell below and execute

# %%
# Replace <MY_GLUE_S3_IAM_ROLE_ARN> with your IAM AWS S3 access role ARN
MY_GLUE_S3_IAM_ROLE_ARN='arn:aws:iam::094271313368:role/jramizares_iceberg_lab_s3_role'

# %% [markdown]
# #### Step 2: Create an external volume
#
# References:
# - Snowflake Documentation: [Configure an external volume for Iceberg tables](https://docs.snowflake.com/en/user-guide/tables-iceberg-configure-external-volume)

# %%
# %%sql
# use role support_rl;
# create or replace external volume {SNOW_USER}_glue_ext_vol
#     storage_locations = (
#         (
#             name = 's3_iceberg_glue_unmanaged'
#             storage_provider = 's3'
#             storage_base_url = 's3://kt-s3-us-west-2/'
#             storage_aws_role_arn = '{MY_GLUE_S3_IAM_ROLE_ARN}'
#             encryption = (type='aws_sse_s3')
#         )
#     )
# ;
# desc external volume {SNOW_USER}_glue_ext_vol;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 3 rows affected.
# [('', 'ALLOW_WRITES', 'Boolean', 'true', 'true'),
#  ('STORAGE_LOCATIONS', 'STORAGE_LOCATION_1', 'String', '{"NAME":"s3_iceberg_glue_unmanaged","STORAGE_PROVIDER":"S3","STORAGE_BASE_URL":"s3://kt-s3-us-west-2/","STORAGE_ALLOWED_LOCATIONS":["s3://kt-s3-us-we ... (126 characters truncated) ... n:aws:iam::291522143594:user/m3ig0000-s","STORAGE_AWS_EXTERNAL_ID":"ZZB08069_SFCRole=61_VSueYd8/om9IWqaFQ2QoisfpX0g=","ENCRYPTION_TYPE":"AWS_SSE_S3"}', ''),
#  ('STORAGE_LOCATIONS', 'ACTIVE', 'String', '', '')]

# %% [markdown]
# NOTE: After creating the external volume, you must update trust relationships in your AWS IAM role based on the `DESCRIBE` output above

# %% [markdown]
# #### Step 3: Create an IAM role with AWS Glue service permissions
#
# NOTE: Run the cell below to generate instructions

# %%
from IPython.display import Markdown as md

here = """
<u>Instructions</u>:
1. In the AWS CE-Sandbox Console, navigate to **Identity and Access Management (IAM)** > [**Roles**](https://us-east-1.console.aws.amazon.com/iam/home#/roles)
2. Click the **Create role** button
3. On the **Specify permissions page**, click the **JSON** button to toggle to the JSON editor
4. Select **Trusted entity type** > **AWS account**
5. Click the **Next** button
6. On the **Add permissions** page, lookup and click the checkbox for **kterada_custom_glue_policy**
7. Click the **Next** button
8. Name the role **{username}_glue_role**
9. Click the **Create role** button
10. Replace `<MY_GLUE_SERVICE_IAM_ROLE_ARN>` with the IAM role ARN in the cell below and execute
""".format(my_s3_bucket=MY_OS_S3_BUCKET, username=SNOW_USER, db_name=TARGET_DB_NAME, table_name=TARGET_TABLE_NAME, source_table=SOURCE_TABLE)

md(here)
# Out:
# <u>Instructions</u>:
# 1. In the AWS CE-Sandbox Console, navigate to **Identity and Access Management (IAM)** > [**Roles**](https://us-east-1.console.aws.amazon.com/iam/home#/roles)
# 2. Click the **Create role** button
# 3. On the **Specify permissions page**, click the **JSON** button to toggle to the JSON editor
# 4. Select **Trusted entity type** > **AWS account**
# 5. Click the **Next** button
# 6. On the **Add permissions** page, lookup and click the checkbox for **kterada_custom_glue_policy**
# 7. Click the **Next** button
# 8. Name the role **jramizares_glue_role**
# 9. Click the **Create role** button
# 10. Replace `<MY_GLUE_SERVICE_IAM_ROLE_ARN>` with the IAM role ARN in the cell below and execute

# %%
# Replace <MY_GLUE_SERVICE_IAM_ROLE_ARN> with your IAM AWS Glue service access role ARN
MY_GLUE_SERVICE_IAM_ROLE_ARN='arn:aws:iam::094271313368:role/jramizares_glue_role'

# %% [markdown]
# #### Step 4: Create a catalog integration
#
# References:
# - Snowflake Documentation: [Configure a catalog integration for Iceberg tables](https://docs.snowflake.com/en/user-guide/tables-iceberg-configure-catalog-integration)

# %% [markdown]
# AWS GLUE (ICEBERG)

# %%
# %%sql
#
# use role support_rl;
# create or replace catalog integration {SNOW_USER}_glue_cat_int
#     catalog_source = glue
#     catalog_namespace = 'kterada_db'
#     table_format = iceberg
#     glue_aws_role_arn = '{MY_GLUE_SERVICE_IAM_ROLE_ARN}'
#     glue_catalog_id = '094271313368'
#     glue_region = 'us-west-2'
#     enabled = true
# ;
# desc integration {SNOW_USER}_glue_cat_int;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 10 rows affected.
# [('ENABLED', 'Boolean', 'true', 'false'),
#  ('CATALOG_SOURCE', 'String', 'GLUE', ''),
#  ('CATALOG_NAMESPACE', 'String', 'kterada_db', ''),
#  ('TABLE_FORMAT', 'String', 'ICEBERG', ''),
#  ('GLUE_AWS_ROLE_ARN', 'String', 'arn:aws:iam::094271313368:role/jramizares_glue_role', ''),
#  ('GLUE_CATALOG_ID', 'String', '094271313368', ''),
#  ('GLUE_REGION', 'String', 'us-west-2', ''),
#  ('GLUE_AWS_IAM_USER_ARN', 'String', 'arn:aws:iam::291522143594:user/m3ig0000-s', ''),
#  ('GLUE_AWS_EXTERNAL_ID', 'String', 'ZZB08069_SFCRole=61_73XDZg7uKMx5sn7He2ivGPfqGU0=', ''),
#  ('COMMENT', 'String', '', '')]

# %% [markdown]
# NOTE: After creating the catalog integration, you must update trust relationships in your AWS IAM role based on the `DESCRIBE` output above

# %% [markdown]
# #### Step 4: Create the unmanaged Snowflake Iceberg table
#
# References:
# - Snowflake Documentation: [Create an Iceberg table](https://docs.snowflake.com/user-guide/tables-iceberg-create)

# %% [markdown]
# AWS GLUE (ICEBERG)

# %%
# %%sql
#
# use role support_rl;
# create or replace iceberg table {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_glue_iceberg_web_sales_t
#     external_volume = {SNOW_USER}_glue_ext_vol
#     catalog = {SNOW_USER}_glue_cat_int
#     catalog_namespace = 'kterada_db'
#     catalog_table_name = 'kt_glue_iceberg_tpcds_sf10tcl_web_sales'
# ;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# [('Table JRAMIZARES_UNMANAGED_GLUE_ICEBERG_WEB_SALES_T successfully created.',)]

# %%
# %%sql
#
# use role support_rl;
# use warehouse {SNOW_USER}_wh;
# select
#     count(*)
# from {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_glue_iceberg_web_sales_t
# where true
# ;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [(1000000,)]

# %%
# %%sql
#
# use role support_rl;
# use warehouse {SNOW_USER}_wh;
# select
#     *
# from {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_glue_iceberg_web_sales_t
# where true
# limit 100
# ;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# (snowflake.connector.errors.ProgrammingError) 002003 (42S02): SQL compilation error:
# Object 'JRAMIZARES_DB.ICEBERG.JRAMIZARES_UNMANAGED_GLUE_ICEBERG_WEB_SALES_T' does not exist or not authorized.
# [SQL: select
#     *
# from jramizares_db.iceberg.jramizares_unmanaged_glue_iceberg_web_sales_t
# where true
# limit 100
# ;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### Exercise 2: Cleanup (Optional)
#
# Execute the cell below to drop the Snowflake objects created in this exercise.

# %%
# %%sql
#
# use role support_rl;
# use {SNOW_USER}_db.iceberg;
# drop iceberg table if exists {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_glue_iceberg_web_sales_t;
# drop catalog integration if exists {SNOW_USER}_glue_cat_int;
# drop external volume if exists {SNOW_USER}_glue_ext_vol;
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [('JRAMIZARES_GLUE_EXT_VOL successfully dropped.',)]

# %% [markdown]
# ### Exercise 3: Convert Unmanaged to Managed Iceberg Table

# %% [markdown]
# #### Step 1: Review the current Iceberg table catalog

# %%
# %%sql
#
# select get_ddl('table','{SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t');
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# [("create or replace ICEBERG TABLE JRAMIZARES_UNMANAGED_OS_ICEBERG_WEB_SALES_T \n EXTERNAL_VOLUME = 'JRAMIZARES_OS_EXT_VOL'\n CATALOG = 'JRAMIZARES_OS_I ... (2 characters truncated) ... BERG_CAT_INT'\n METADATA_FILE_PATH = 'iceberg_feature_lab/tpcds_sf10tcl/web_sales/metadata/00000-31cc49ef-7184-42cd-a697-2e6fc32863e1.metadata.json';",)]

# %% [markdown]
# #### Step 2: Convert the unmanaged Iceberg table to managed

# %%
# %%sql
#
# alter iceberg table {SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t convert to managed base_location='snowflake/web_sales_t';
# Out:
#  * snowflake://jramizares:***@sfcsupport-feature_training/jramizares_iceberg_db?role=support_rl&warehouse=jramizares_wh
# 1 rows affected.
# [('Statement executed successfully.',)]

# %% [markdown]
# #### Step 3: Confirm if the catalog was converted to Snowflake

# %%
# %%sql
#
# select get_ddl('table','{SNOW_USER}_db.iceberg.{SNOW_USER}_unmanaged_os_iceberg_web_sales_t');
